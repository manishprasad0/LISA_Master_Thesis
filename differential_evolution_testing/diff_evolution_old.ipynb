# %%
import os
import sys
sys.path.append(os.path.abspath(".."))

import numpy as np
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'retina'  # For sharper figures, but it takes more time
from tqdm import tqdm
import scipy as sp
from copy import deepcopy 

# LISA tools
from lisatools.utils.constants import *
from lisatools.sensitivity  import AE1SensitivityMatrix, AET1SensitivityMatrix

# BBHX: Suppress the print statements from the BBHX module like: "No CuPy or GPU PhenomHM module"
# This is done to avoid cluttering the output when running sp.optimize.differential_evolution
from contextlib import contextmanager

@contextmanager
def suppress_stdout():
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        sys.stdout = devnull
        try:
            yield
        finally:
            sys.stdout = old_stdout

with suppress_stdout():
    from bbhx.waveformbuild import BBHWaveformFD

# My modules
from tools.LISASimulator import LISASimulator
from tools.time_freq_likelihood import TimeFreqLikelihood
from tools.likelihood import get_dh, get_hh, TimeFreqSNR
import tools.likelihood as likelihood
from tools.MBHB_differential_evolution_old import MBHB_finder_time_frequency, MBHB_finder_lisatools, MBHB_finder_frequency_domain, transform_bbhx_to_parameters, transform_parameters_to_bbhx

# %%
from multiprocessing import cpu_count
print(cpu_count())
# Out:
# 11

# %%
Tobs = YRSID_SI/12
dt = 5.
include_T_channel = False # Set to True if you want to include the T channel in the simulation, otherwise only A and E channels will be included.

wave_gen = BBHWaveformFD(amp_phase_kwargs=dict(run_phenomd=False))
sim = LISASimulator(Tobs=Tobs, dt=dt, wave_gen=wave_gen, include_T_channel=include_T_channel)

m1 = 3e5
m2 = 1.5e5
a1 = 0.2
a2 = 0.4
dist = 4 * PC_SI * 1e9  # distance in Gpc
phi_ref = np.pi/2
f_ref = 0.0
inc = np.pi/3
lam = np.pi/1.
beta = np.pi/4.
psi = np.pi/4.
t_ref = 0.95 * Tobs
#t_ref = round(0.9 * Tobs / dt) * dt  # round to the nearest multiple of dt, to force t_ref to be a part of t_array

parameters = np.array([m1, m2, a1, a2, dist, phi_ref, f_ref, inc, lam, beta, psi, t_ref])

m1_2 = 8e5 # 1e5
m2_2 = 2e5 # 1e5
a1_2 = 0.5
a2_2 = 0.7
dist_2 = 200 * 1e9 * PC_SI # lower distance try this 
phi_ref_2 = 0.0
f_ref_2 = 0.0
inc_2 = np.pi/3.
lam_2 = np.pi  # ecliptic longitude
beta_2 = np.pi/2. # ecliptic latitude
psi_2 = np.pi/6.  # polarization angle
t_ref_2 = 0.95 * Tobs

parameters_2 = np.array([m1_2, m2_2, a1_2, a2_2, dist_2, phi_ref_2, f_ref_2, inc_2, lam_2, beta_2, psi_2, t_ref_2])

modes = [(2,2), (2,1), (3,3), (3,2), (4,4), (4,3)]
waveform_kwargs = dict(length=1024, direct=False, fill=True, squeeze=False, modes=modes)

data_t, data_f, f_array, t_array, sens_mat = sim(seed = 42, parameters=parameters, waveform_kwargs=waveform_kwargs)
waveform_kwargs.update(freqs=f_array)

print(sim.SNR_optimal()[0])
# Out:
# 3595.48440646233

# %%
#plt.plot(t_array[:10000], data_t[0][:10000])
plt.loglog(f_array, np.abs(data_f[0]), label="A channel")

# %% [markdown]
# ## Pre-Merger

# %%
# Not doing the premerger now to see if the code works better with the merger included
time_before_merger = 6*60*60
cutoff_time = t_ref - time_before_merger
max_time = t_ref + 12*60*60

def pre_merger(gravitational_wave_data_t, time_before_merger, t_ref, t_array):
        cutoff_time = t_ref - time_before_merger
        cutoff_index = np.searchsorted(t_array, cutoff_time)
        data_t_truncated = gravitational_wave_data_t[:, :cutoff_index]
        return data_t_truncated, cutoff_index

data_t_truncated,   cutoff_index =  pre_merger(data_t, time_before_merger, t_ref, t_array)
signal_t_truncated, cutoff_index =  pre_merger(sim.signal_t[0], time_before_merger, t_ref, t_array)

# %% [markdown]
# # Differential Evolution Analysis

# %%
boundaries = {}
boundaries['Total_Mass'] = [np.log(1e5), np.log(6e5)]   
boundaries['Mass_Ratio'] = [0.05, 0.999999]
boundaries['Spin1'] = [-1, 1]
boundaries['Spin2'] = [-1, 1]
boundaries['Distance'] = [1, 10] # in GPc i.e. dL / (PC_SI * 1e9)
boundaries['Phase'] = [0.0, 2 * np.pi]
boundaries['cos(Inclination)'] = [-1, 1]
boundaries['Ecliptic_Longitude'] = [0, 2*np.pi]
boundaries['sin(Ecliptic_Latitude)'] = [-1, 1]
boundaries['Polarization'] = [0, np.pi]
#boundaries['Coalescence_Time'] = [cutoff_time, max_time]  
boundaries['Coalescence_Time'] = [0, max_time - cutoff_time]

# %%
number_of_searches = 1

differential_evolution_kwargs = {
    'strategy': 'best1bin',
    'popsize': 15,
    'tol': 1e-8,
    'maxiter': 100,
    'recombination': 0.9,
    'mutation': (0.4, 0.8),
    'polish': True,
    'disp': True,
    'workers': -1,
    'updating': 'deferred',
    'init': 'latinhypercube',
}

fixed_parameters = {
    #'Total_Mass': np.log(m1 + m2),
    #'Mass_Ratio': m2 / m1,
    #'Spin1': a1,
    #'Spin2': a2,
    'Distance': boundaries['Distance'][0] + 0.5 * (boundaries['Distance'][1] - boundaries['Distance'][0]), # Always include distance in fixed parameters
    #'Phase': phi_ref,
    #'cos(Inclination)': np.cos(inc),
    #'Ecliptic_Longitude': lam,
    #'sin(Ecliptic_Latitude)': np.sin(beta),
    #'Polarization': psi,
    #'Coalescence_Time': t_ref,
}

# %% [markdown]
# # Time Frequency Domain

# %%
analysis = TimeFreqSNR(
    data_t_truncated,
    wave_gen=wave_gen,
    nperseg=5000,
    dt_full=dt,
    cutoff_index=cutoff_index,
    pre_merger=True
)
analysis.get_stft_of_data()
SNR, amplitude = analysis.calculate_time_frequency_SNR(*parameters, waveform_kwargs=waveform_kwargs)
new_distance = dist /  amplitude
print((new_distance - dist)/(PC_SI*1e9) , (new_distance-dist)/dist)
print( "True distance       = ",  dist/(PC_SI*1e9), "Gpc")
print( "Dist from Amplitude = ",  new_distance/(PC_SI*1e9), "Gpc")
print( "SNR calculated      = ",  SNR)
# Out:
# 0.0009307704902833732 0.0002326926225708433
# True distance       =  4.0 Gpc
# Dist from Amplitude =  4.0009307704902835 Gpc
# SNR calculated      =  0.3867966219603031

# %%
# For full signal, use data_t =  sim.signal_t[0] , set pre_merger=False, and comment   cutoff_index = cutoff_index
# For pre-merger,  use data_t =  data_t_truncated, set pre_merger=True , and uncomment cutoff_index = cutoff_index
DifferentialEvolution_time_frequency_1 = MBHB_finder_time_frequency(
    data_t = data_t_truncated,
    wave_gen= wave_gen,
    waveform_kwargs=waveform_kwargs,
    boundaries=boundaries,
    nperseg=5000,
    dt_full= dt,
    pre_merger=True,
    cutoff_index=cutoff_index,
    cutoff_time=cutoff_time,
    true_parameters=parameters,
)
DifferentialEvolution_time_frequency_1.get_stft_of_data()
found_parameters_tf_1, found_snr_found_tf_1, results_tf_1, parameters_history_1 = DifferentialEvolution_time_frequency_1.find_MBHB(number_of_searches=number_of_searches,
                                                                                                                                   differential_evolution_kwargs=differential_evolution_kwargs, 
                                                                                                                                   fixed_parameters=fixed_parameters)
# Out:
# time SNR  0.27
# initial guess -0.009305349706893543
# No CuPy
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# differential_evolution step 1: f(x)= -0.20911229601388237
# differential_evolution step 2: f(x)= -0.20911229601388237
# differential_evolution step 3: f(x)= -0.20911229601388237
# differential_evolution step 4: f(x)= -0.32529273934443353
# differential_evolution step 5: f(x)= -0.32529273934443353
# differential_evolution step 6: f(x)= -0.32529273934443353
# differential_evolution step 7: f(x)= -0.32529273934443353
# differential_evolution step 8: f(x)= -0.32529273934443353
# differential_evolution step 9: f(x)= -0.32529273934443353
# differential_evolution step 10: f(x)= -0.32529273934443353
# differential_evolution step 11: f(x)= -0.32529273934443353
# differential_evolution step 12: f(x)= -0.32529273934443353
# differential_evolution step 13: f(x)= -0.32529273934443353
# differential_evolution step 14: f(x)= -0.32529273934443353
# differential_evolution step 15: f(x)= -0.32529273934443353
# differential_evolution step 16: f(x)= -0.32529273934443353
# differential_evolution step 17: f(x)= -0.3403918830429872
# differential_evolution step 18: f(x)= -0.37879160991656924
# differential_evolution step 19: f(x)= -0.37879160991656924
# differential_evolution step 20: f(x)= -0.37879160991656924
# differential_evolution step 21: f(x)= -0.37879160991656924
# differential_evolution step 22: f(x)= -0.38499042647467197
# differential_evolution step 23: f(x)= -0.3855502268348991
# differential_evolution step 24: f(x)= -0.38627936582780315
# differential_evolution step 25: f(x)= -0.386364733335841
# differential_evolution step 26: f(x)= -0.386364733335841
# differential_evolution step 27: f(x)= -0.3863886028939091
# differential_evolution step 28: f(x)= -0.3863886028939091
# differential_evolution step 29: f(x)= -0.3864763622952857
# differential_evolution step 30: f(x)= -0.38650598445674594
# differential_evolution step 31: f(x)= -0.3865590991761704
# differential_evolution step 32: f(x)= -0.38658718993009034
# differential_evolution step 33: f(x)= -0.3866148352636902
# differential_evolution step 34: f(x)= -0.38662724605193255
# differential_evolution step 35: f(x)= -0.38663427251712784
# differential_evolution step 36: f(x)= -0.3866417488798027
# differential_evolution step 37: f(x)= -0.38664635032196526
# differential_evolution step 38: f(x)= -0.3866542499446369
# differential_evolution step 39: f(x)= -0.3866595461260296
# differential_evolution step 40: f(x)= -0.3866656543998464
# differential_evolution step 41: f(x)= -0.3866748632913181
# differential_evolution step 42: f(x)= -0.38668185204394706
# differential_evolution step 43: f(x)= -0.38668867573209426
# differential_evolution step 44: f(x)= -0.3866930561295748
# differential_evolution step 45: f(x)= -0.3866965233362432
# differential_evolution step 46: f(x)= -0.38670122087696635
# differential_evolution step 47: f(x)= -0.38670531947015824
# differential_evolution step 48: f(x)= -0.3867087323880074
# differential_evolution step 49: f(x)= -0.38671137914578924
# differential_evolution step 50: f(x)= -0.3867154433874732
# differential_evolution step 51: f(x)= -0.3867184666788165
# differential_evolution step 52: f(x)= -0.3867215508935988
# differential_evolution step 53: f(x)= -0.3867240564073178
# differential_evolution step 54: f(x)= -0.3867250422408626
# differential_evolution step 55: f(x)= -0.3867270314358606
# differential_evolution step 56: f(x)= -0.38673019398025493
# differential_evolution step 57: f(x)= -0.3867337751303963
# differential_evolution step 58: f(x)= -0.3867355760923482
# differential_evolution step 59: f(x)= -0.3867390537040904
# differential_evolution step 60: f(x)= -0.38674022584926115
# differential_evolution step 61: f(x)= -0.38674185320746696
# differential_evolution step 62: f(x)= -0.38674264280772336
# differential_evolution step 63: f(x)= -0.3867434793219711
# differential_evolution step 64: f(x)= -0.386744454009741
# differential_evolution step 65: f(x)= -0.3867449933194069
# differential_evolution step 66: f(x)= -0.38674547883891836
# differential_evolution step 67: f(x)= -0.3867459336965473
# differential_evolution step 68: f(x)= -0.3867465310159249
# differential_evolution step 69: f(x)= -0.38674697320005685
# differential_evolution step 70: f(x)= -0.3867474589518459
# differential_evolution step 71: f(x)= -0.38674766528025617
# differential_evolution step 72: f(x)= -0.3867479614361441
# differential_evolution step 73: f(x)= -0.38674863944405036
# differential_evolution step 74: f(x)= -0.38674896251010865
# differential_evolution step 75: f(x)= -0.3867491285166325
# differential_evolution step 76: f(x)= -0.38674933425750857
# differential_evolution step 77: f(x)= -0.38674952754618663
# differential_evolution step 78: f(x)= -0.38674971219864085
# differential_evolution step 79: f(x)= -0.38674999673383453
# differential_evolution step 80: f(x)= -0.38675014521798273
# differential_evolution step 81: f(x)= -0.3867504510739109
# differential_evolution step 82: f(x)= -0.3867508849662712
# differential_evolution step 83: f(x)= -0.3867511724431595
# differential_evolution step 84: f(x)= -0.3867513839730233
# differential_evolution step 85: f(x)= -0.38675162231514837
# differential_evolution step 86: f(x)= -0.3867519491587978
# differential_evolution step 87: f(x)= -0.3867524082203133
# differential_evolution step 88: f(x)= -0.3867527722113198
# differential_evolution step 89: f(x)= -0.38675336410628003
# differential_evolution step 90: f(x)= -0.3867535451178526
# differential_evolution step 91: f(x)= -0.3867539830727126
# differential_evolution step 92: f(x)= -0.38675417450653327
# differential_evolution step 93: f(x)= -0.386754416853363
# differential_evolution step 94: f(x)= -0.3867548118958979
# differential_evolution step 95: f(x)= -0.386755175031303
# differential_evolution step 96: f(x)= -0.3867553617811835
# differential_evolution step 97: f(x)= -0.3867556928089302
# differential_evolution step 98: f(x)= -0.3867558637788545
# differential_evolution step 99: f(x)= -0.38675599962741064
# differential_evolution step 100: f(x)= -0.38675616324784423
# Polishing solution with 'L-BFGS-B'

# %%
print(DifferentialEvolution_time_frequency_1)
print(results_tf_1)
# Out:
# Index Parameter                 Lower Bound    Found 1             True                 Upper Bound     Status
# ------------------------------------------------------------------------------------------------------------------
# 0     Total_Mass                11.5129        13.017              13.017               13.3047         fixed
# 1     Mass_Ratio                0.05           0.5                 0.5                  0.999999        fixed
# 2     Spin1                     -1             0.2                 0.2                  1               fixed
# 3     Spin2                     -1             0.4                 0.4                  1               fixed
# 4     Distance                  1              3.97358             4                    10              variable
# 5     Phase                     0              1.5708              1.5708               6.28319         fixed
# 6     cos(Inclination)          -1             0.5                 0.5                  1               fixed
# 7     Ecliptic_Longitude        0              3.07038             3.14159              6.28319         variable
# 8     sin(Ecliptic_Latitude)    -1             0.517401            0.707107             1               variable
# 9     Polarization              0              0.785398            0.785398             3.14159         fixed
# 10    Coalescence_Time          0              21496.2             21600                64800           variable
#
# SNRs for each run:
# Run 1 : SNR = 0.38675676
#
# [             message: Maximum number of iterations has been exceeded.
#              success: False
#                  fun: -0.38675675746165156
#                    x: [ 3.070e+00  5.174e-01  2.150e+04]
#                  nit: 100
#                 nfev: 4561
#           population: [[ 3.070e+00  5.176e-01  2.150e+04]
#                        [ 3.069e+00  5.154e-01  2.150e+04]
#                        ...
#                        [ 3.070e+00  5.168e-01  2.150e+04]
#                        [ 3.070e+00  5.179e-01  2.150e+04]]
#  population_energies: [-3.868e-01 -3.868e-01 ... -3.868e-01 -3.868e-01]
#                  jac: [ 1.014e-05 -5.246e-06 -1.732e-06]]

# %%
# For full signal, use data_t =  sim.signal_t[0] , set pre_merger=False, and comment   cutoff_index = cutoff_index
# For pre-merger,  use data_t =  data_t_truncated, set pre_merger=True , and uncomment cutoff_index = cutoff_index
DifferentialEvolution_time_frequency_2 = MBHB_finder_time_frequency(
    data_t = data_t_truncated,
    wave_gen= wave_gen,
    waveform_kwargs=waveform_kwargs,
    boundaries=boundaries,
    nperseg=5000,
    dt_full= dt,
    pre_merger=True,
    cutoff_index=cutoff_index,
    cutoff_time=cutoff_time,
    true_parameters=parameters,
)
DifferentialEvolution_time_frequency_2.get_stft_of_data()
differential_evolution_kwargs_2 = {
    'strategy': 'best1bin',
    'popsize': 15,
    'tol': 1e-8,
    'maxiter': 200,
    'recombination': 0.9,
    'mutation': (0.4, 0.8),
    'polish': True,
    'disp': True,
    'workers': -1,
    'updating': 'deferred',
    'init': 'latinhypercube',
}


found_parameters_tf_2, found_snr_found_tf_2, results_tf_2, parameters_history_2 = DifferentialEvolution_time_frequency_2.find_MBHB(number_of_searches=number_of_searches,
                                                                             differential_evolution_kwargs=differential_evolution_kwargs_2, 
                                                                             fixed_parameters=fixed_parameters)
# Out:
# time SNR  0.27
# initial guess 0.003980823156079058
# No CuPy
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU response available.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# differential_evolution step 1: f(x)= -0.041408595590312486
# differential_evolution step 2: f(x)= -0.04223577707952087
# differential_evolution step 3: f(x)= -0.06288240144327044
# differential_evolution step 4: f(x)= -0.12443970354813455
# differential_evolution step 5: f(x)= -0.12443970354813455
# differential_evolution step 6: f(x)= -0.3452603857126515
# differential_evolution step 7: f(x)= -0.3452603857126515
# differential_evolution step 8: f(x)= -0.3452603857126515
# differential_evolution step 9: f(x)= -0.3592946855586633
# differential_evolution step 10: f(x)= -0.3592946855586633
# differential_evolution step 11: f(x)= -0.3592946855586633
# differential_evolution step 12: f(x)= -0.38182660895903564
# differential_evolution step 13: f(x)= -0.38182660895903564
# differential_evolution step 14: f(x)= -0.3818754552191989
# differential_evolution step 15: f(x)= -0.382877143032149
# differential_evolution step 16: f(x)= -0.3865922213482276
# differential_evolution step 17: f(x)= -0.3865922213482276
# differential_evolution step 18: f(x)= -0.3865922213482276
# differential_evolution step 19: f(x)= -0.3865922213482276
# differential_evolution step 20: f(x)= -0.3865922213482276
# differential_evolution step 21: f(x)= -0.3866065410552733
# differential_evolution step 22: f(x)= -0.3866485819761897
# differential_evolution step 23: f(x)= -0.3866785373753942
# differential_evolution step 24: f(x)= -0.3866858818899587
# differential_evolution step 25: f(x)= -0.3867004487614116
# differential_evolution step 26: f(x)= -0.3867099725907183
# differential_evolution step 27: f(x)= -0.38672170295613095
# differential_evolution step 28: f(x)= -0.38672498811330863
# differential_evolution step 29: f(x)= -0.3867317709566523
# differential_evolution step 30: f(x)= -0.3867349141321193
# differential_evolution step 31: f(x)= -0.38673942866739236
# differential_evolution step 32: f(x)= -0.3867423000157876
# differential_evolution step 33: f(x)= -0.3867465251940855
# differential_evolution step 34: f(x)= -0.38675063956563643
# differential_evolution step 35: f(x)= -0.38675220324270027
# differential_evolution step 36: f(x)= -0.3867538193662842
# differential_evolution step 37: f(x)= -0.3867554356334575
# differential_evolution step 38: f(x)= -0.38675701195702666
# differential_evolution step 39: f(x)= -0.386757673953592
# differential_evolution step 40: f(x)= -0.38675894315016357
# differential_evolution step 41: f(x)= -0.3867599954806413
# differential_evolution step 42: f(x)= -0.3867611273916054
# differential_evolution step 43: f(x)= -0.38676178987402643
# differential_evolution step 44: f(x)= -0.3867631252742678
# differential_evolution step 45: f(x)= -0.3867639975079083
# differential_evolution step 46: f(x)= -0.38676555807777036
# differential_evolution step 47: f(x)= -0.3867668532470093
# differential_evolution step 48: f(x)= -0.38676843935217037
# differential_evolution step 49: f(x)= -0.38676975597769386
# differential_evolution step 50: f(x)= -0.3867712274099614
# differential_evolution step 51: f(x)= -0.38677165637696387
# differential_evolution step 52: f(x)= -0.38677222480059115
# differential_evolution step 53: f(x)= -0.3867728768829014
# differential_evolution step 54: f(x)= -0.3867735219925819
# differential_evolution step 55: f(x)= -0.38677540985647224
# differential_evolution step 56: f(x)= -0.3867761956398238
# differential_evolution step 57: f(x)= -0.3867770318506669
# differential_evolution step 58: f(x)= -0.38677773220189693
# differential_evolution step 59: f(x)= -0.3867785303027323
# differential_evolution step 60: f(x)= -0.38677897930657157
# differential_evolution step 61: f(x)= -0.3867794544778732
# differential_evolution step 62: f(x)= -0.38677983837749225
# differential_evolution step 63: f(x)= -0.38678044382026416
# differential_evolution step 64: f(x)= -0.3867807571204016
# differential_evolution step 65: f(x)= -0.3867815319758558
# differential_evolution step 66: f(x)= -0.38678219557108234
# differential_evolution step 67: f(x)= -0.3867829925636733
# differential_evolution step 68: f(x)= -0.38678348562269443
# differential_evolution step 69: f(x)= -0.3867839558485163
# differential_evolution step 70: f(x)= -0.3867843836019488
# differential_evolution step 71: f(x)= -0.38678496323133493
# differential_evolution step 72: f(x)= -0.3867852607611189
# differential_evolution step 73: f(x)= -0.3867855170278022
# differential_evolution step 74: f(x)= -0.3867857726200255
# differential_evolution step 75: f(x)= -0.38678654090045744
# differential_evolution step 76: f(x)= -0.38678689398102445
# differential_evolution step 77: f(x)= -0.38678741730141464
# differential_evolution step 78: f(x)= -0.3867876683894842
# differential_evolution step 79: f(x)= -0.3867879449863516
# differential_evolution step 80: f(x)= -0.38678819046299456
# differential_evolution step 81: f(x)= -0.3867887167594694
# differential_evolution step 82: f(x)= -0.3867891186428112
# differential_evolution step 83: f(x)= -0.3867893991128397
# differential_evolution step 84: f(x)= -0.38678986258652803
# differential_evolution step 85: f(x)= -0.38679020492107297
# differential_evolution step 86: f(x)= -0.38679075776381355
# differential_evolution step 87: f(x)= -0.3867910756266232
# differential_evolution step 88: f(x)= -0.38679148532954133
# differential_evolution step 89: f(x)= -0.3867919728312001
# differential_evolution step 90: f(x)= -0.38679271592714976
# differential_evolution step 91: f(x)= -0.386793063936862
# differential_evolution step 92: f(x)= -0.38679326029377736
# differential_evolution step 93: f(x)= -0.38679338697359006
# differential_evolution step 94: f(x)= -0.3867935039237758
# differential_evolution step 95: f(x)= -0.3867939898889384
# differential_evolution step 96: f(x)= -0.38679421413854326
# differential_evolution step 97: f(x)= -0.3867945134921481
# differential_evolution step 98: f(x)= -0.38679473385347785
# differential_evolution step 99: f(x)= -0.38679491301370955
# differential_evolution step 100: f(x)= -0.3867950510625839
# differential_evolution step 101: f(x)= -0.3867952606210854
# differential_evolution step 102: f(x)= -0.38679540477088437
# differential_evolution step 103: f(x)= -0.38679551941727236
# differential_evolution step 104: f(x)= -0.3867956309906512
# differential_evolution step 105: f(x)= -0.3867956999996977
# differential_evolution step 106: f(x)= -0.38679576999194565
# differential_evolution step 107: f(x)= -0.3867958304921227
# differential_evolution step 108: f(x)= -0.3867959008995928
# differential_evolution step 109: f(x)= -0.38679597436547486
# differential_evolution step 110: f(x)= -0.3867960238386018
# differential_evolution step 111: f(x)= -0.386796106817676
# differential_evolution step 112: f(x)= -0.386796185950083
# differential_evolution step 113: f(x)= -0.3867963091939009
# differential_evolution step 114: f(x)= -0.3867963560592302
# differential_evolution step 115: f(x)= -0.38679645370694005
# differential_evolution step 116: f(x)= -0.3867964826727356
# differential_evolution step 117: f(x)= -0.38679655060434526
# differential_evolution step 118: f(x)= -0.3867965846679451
# differential_evolution step 119: f(x)= -0.3867966278888024
# differential_evolution step 120: f(x)= -0.38679668795224803
# differential_evolution step 121: f(x)= -0.3867967339675549
# differential_evolution step 122: f(x)= -0.3867967874553766
# differential_evolution step 123: f(x)= -0.38679684408082854
# differential_evolution step 124: f(x)= -0.38679689830311303
# differential_evolution step 125: f(x)= -0.386796960734923
# differential_evolution step 126: f(x)= -0.38679701394424
# differential_evolution step 127: f(x)= -0.38679706828017985
# differential_evolution step 128: f(x)= -0.386797101404894
# differential_evolution step 129: f(x)= -0.386797151673525
# differential_evolution step 130: f(x)= -0.38679720268071055
# differential_evolution step 131: f(x)= -0.38679721969367115
# differential_evolution step 132: f(x)= -0.38679722789731674
# differential_evolution step 133: f(x)= -0.3867972370047593
# differential_evolution step 134: f(x)= -0.38679726041127244
# differential_evolution step 135: f(x)= -0.38679727095170846
# differential_evolution step 136: f(x)= -0.3867972867187305
# differential_evolution step 137: f(x)= -0.38679729406552216
# differential_evolution step 138: f(x)= -0.3867973013062584
# differential_evolution step 139: f(x)= -0.38679730394263734
# differential_evolution step 140: f(x)= -0.38679731218312974
# differential_evolution step 141: f(x)= -0.3867973172758063
# differential_evolution step 142: f(x)= -0.3867973252239648
# differential_evolution step 143: f(x)= -0.3867973260723966
# Polishing solution with 'L-BFGS-B'

# %%
print(DifferentialEvolution_time_frequency_2)
print(results_tf_2)
# Out:
# Index Parameter                 Lower Bound    Found 1             True                 Upper Bound     Status
# ------------------------------------------------------------------------------------------------------------------
# 0     Total_Mass                11.5129        13.017              13.017               13.3047         fixed
# 1     Mass_Ratio                0.05           0.5                 0.5                  0.999999        fixed
# 2     Spin1                     -1             0.2                 0.2                  1               fixed
# 3     Spin2                     -1             0.4                 0.4                  1               fixed
# 4     Distance                  1              3.99695             4                    10              variable
# 5     Phase                     0              1.5708              1.5708               6.28319         fixed
# 6     cos(Inclination)          -1             0.5                 0.5                  1               fixed
# 7     Ecliptic_Longitude        0              3.14838             3.14159              6.28319         variable
# 8     sin(Ecliptic_Latitude)    -1             0.717422            0.707107             1               variable
# 9     Polarization              0              0.785398            0.785398             3.14159         fixed
# 10    Coalescence_Time          0              21606.6             21600                64800           variable
#
# SNRs for each run:
# Run 1 : SNR = 0.38679733
#
# [             message: Optimization terminated successfully.
#              success: True
#                  fun: -0.38679732628171287
#                    x: [ 3.148e+00  7.174e-01  2.161e+04]
#                  nit: 143
#                 nfev: 6492
#           population: [[ 3.148e+00  7.174e-01  2.161e+04]
#                        [ 3.148e+00  7.169e-01  2.161e+04]
#                        ...
#                        [ 3.147e+00  7.157e-01  2.161e+04]
#                        [ 3.148e+00  7.173e-01  2.161e+04]]
#  population_energies: [-3.868e-01 -3.868e-01 ... -3.868e-01 -3.868e-01]
#                  jac: [-8.432e-06 -1.061e-05 -7.593e-06]]

# %%
# For full signal, use data_t =  sim.signal_t[0] , set pre_merger=False, and comment   cutoff_index = cutoff_index
# For pre-merger,  use data_t =  data_t_truncated, set pre_merger=True , and uncomment cutoff_index = cutoff_index
DifferentialEvolution_time_frequency_3 = MBHB_finder_time_frequency(
    data_t = data_t_truncated,
    wave_gen= wave_gen,
    waveform_kwargs=waveform_kwargs,
    boundaries=boundaries,
    nperseg=5000,
    dt_full= dt,
    pre_merger=True,
    cutoff_index=cutoff_index,
    cutoff_time=cutoff_time,
    true_parameters=parameters,
)
DifferentialEvolution_time_frequency_3.get_stft_of_data()

found_parameters_tf_3, found_snr_found_tf_3, results_tf_3 = DifferentialEvolution_time_frequency_3.find_MBHB(number_of_searches=number_of_searches,
                                                                             differential_evolution_kwargs=differential_evolution_kwargs, 
                                                                             fixed_parameters=fixed_parameters)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 17
#       3 DifferentialEvolution_time_frequency_3 = MBHB_finder_time_frequency(
#       4     data_t = data_t_truncated,
#       5     wave_gen= wave_gen,
#    (...)     13     true_parameters=parameters,
#      14 )
#      15 DifferentialEvolution_time_frequency_3.get_stft_of_data()
# ---> 17 found_parameters_tf_3, found_snr_found_tf_3, results_tf_3 = DifferentialEvolution_time_frequency_3.find_MBHB(number_of_searches=number_of_searches,
#      18                                                                              differential_evolution_kwargs=differential_evolution_kwargs,
#      19                                                                              fixed_parameters=fixed_parameters)
#
# File ~/Documents/LISA_Master_Thesis/tools/MBHB_differential_evolution_old.py:327, in MBHB_finder_time_frequency.find_MBHB(self, number_of_searches, differential_evolution_kwargs, fixed_parameters)
#     324 initial_guess_without_distance = np.random.uniform(low=bounds[:, 0], high=bounds[:, 1])
#     326 time_start = time.time()
# --> 327 SNR = self.calculate_time_frequency_SNR_without_distance(variable_parameters=initial_guess_without_distance, fixed_parameters=fixed_parameters)
#     328 print('time SNR ',np.round(time.time() - time_start,2))
#     329 print('initial guess', SNR)
#
# File ~/Documents/LISA_Master_Thesis/tools/MBHB_differential_evolution_old.py:289, in MBHB_finder_time_frequency.calculate_time_frequency_SNR_without_distance(self, variable_parameters, fixed_parameters)
#     287 # Truncate the template to the same length as the data i.e. pre-merger
#     288 if self.pre_merger:
# --> 289     template_t = template_t[:, :self.cutoff_index]
#     291 # Calculate the STFT of the template
#     292 Zxx_temp_A = sp.signal.stft(template_t[0], fs=1/self.dt, nperseg=self.nperseg)[2]
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %%
print(DifferentialEvolution_time_frequency_3)
print(results_tf_3)
# Out:
# Index Parameter                 Lower Bound    Found 1             True                 Upper Bound     Status
# ------------------------------------------------------------------------------------------------------------------
# 0     Total_Mass                100000         445806              450000               600000          variable
# 1     Mass_Ratio                0.05           0.525472            0.5                  0.999999        variable
# 2     Spin1                     -1             -0.0388861          0.2                  1               variable
# 3     Spin2                     -1             0.918805            0.4                  1               variable
# 4     Distance                  1000           2429                4000                 10000           variable
# 5     Phase                     0              4.83071             1.5708               6.28319         variable
# 6     cos(Inclination)          -1             -0.419214           0.5                  1               variable
# 7     Ecliptic_Longitude        0              1.71396             3.14159              6.28319         variable
# 8     sin(Ecliptic_Latitude)    -1             -0.924543           0.707107             1               variable
# 9     Polarization              0              0.993081            0.785398             3.14159         variable
# 10    Coalescence_Time          2.49475e+06    2.4991e+06          2.49835e+06          2.54155e+06     variable
#
# SNRs for each run:
# Run 1 : SNR = 0.72834336
#
# [             message: Optimization terminated successfully.
#              success: True
#                  fun: -0.7283433551731109
#                    x: [ 4.458e+05  5.255e-01 -3.889e-02  9.188e-01
#                         4.831e+00 -4.192e-01  1.714e+00 -9.245e-01
#                         9.931e-01  2.499e+06]
#                  nit: 356
#                 nfev: 35832
#           population: [[ 4.458e+05  5.255e-01 ...  9.931e-01  2.499e+06]
#                        [ 4.458e+05  5.255e-01 ...  9.925e-01  2.499e+06]
#                        ...
#                        [ 4.458e+05  5.255e-01 ...  9.922e-01  2.499e+06]
#                        [ 4.458e+05  5.255e-01 ...  9.921e-01  2.499e+06]]
#  population_energies: [-7.283e-01 -7.283e-01 ... -7.283e-01 -7.283e-01]
#                  jac: [ 7.796e-06  1.578e-04  3.873e-04  4.763e-06
#                        -4.685e-06 -4.489e-04  4.938e-04 -1.972e-04
#                         2.890e-04  1.194e-05]]

# %%
analysis = TimeFreqSNR(
    sim.signal_t[0],
    wave_gen=wave_gen,
    nperseg=5000,
    dt_full=dt,
    cutoff_index=cutoff_index,
    pre_merger=False
)
analysis.get_stft_of_data()
SNR, amplitude = analysis.calculate_time_frequency_SNR(*parameters, waveform_kwargs=waveform_kwargs)
new_distance = dist /  amplitude
print((new_distance - dist)/(PC_SI*1e9) , (new_distance-dist)/dist)
print( "True distance       = ",  dist/(PC_SI*1e9), "Gpc")
print( "Dist from Amplitude = ",  new_distance/(PC_SI*1e9), "Gpc")
print( "SNR calculated      = ",  SNR)
# Out:
# 0.0 0.0
# True distance       =  4.0 Gpc
# Dist from Amplitude =  4.0 Gpc
# SNR calculated      =  1.2772543789153916

# %%
# For full signal, use data_t =  sim.signal_t[0] , set pre_merger=False, and comment   cutoff_index = cutoff_index
# For pre-merger,  use data_t =  data_t_truncated, set pre_merger=True , and uncomment cutoff_index = cutoff_index
differential_evolution_kwargs_4 = {
    'strategy': 'best1exp',
    'popsize': 10,
    'tol': 1e-8,
    'maxiter': 1000,
    'recombination': 1,
    'mutation': (0.5, 1.0),
    'polish': True,
    'disp': True,
    'workers': -1,  # Use all available CPU cores
    'updating': 'deferred',
}

DifferentialEvolution_time_frequency_4 = MBHB_finder_time_frequency(
    data_t = sim.signal_t[0],
    wave_gen= wave_gen,
    waveform_kwargs=waveform_kwargs,
    boundaries=boundaries,
    nperseg=5000,
    dt_full= dt,
    pre_merger=False,
    #cutoff_index=cutoff_index,
    true_parameters=parameters,
)
DifferentialEvolution_time_frequency_4.get_stft_of_data()

found_parameters_tf_4, found_snr_found_tf_4, results_tf_4 = DifferentialEvolution_time_frequency_4.find_MBHB(number_of_searches=number_of_searches,
                                                                             differential_evolution_kwargs=differential_evolution_kwargs_4, 
                                                                             fixed_parameters=fixed_parameters)
# Out:
# time SNR  0.2
# initial guess 0.027760634579982197
# No CuPy
# No CuPy
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy or GPU response available.
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# differential_evolution step 1: f(x)= -0.1187939112308194
# differential_evolution step 2: f(x)= -0.1187939112308194
# differential_evolution step 3: f(x)= -0.18437929098968586
# differential_evolution step 4: f(x)= -0.18437929098968586
# differential_evolution step 5: f(x)= -0.21962890072036728
# differential_evolution step 6: f(x)= -0.4560228655007275
# differential_evolution step 7: f(x)= -0.4560228655007275
# differential_evolution step 8: f(x)= -0.4560228655007275
# differential_evolution step 9: f(x)= -0.4560228655007275
# differential_evolution step 10: f(x)= -0.4560228655007275
# differential_evolution step 11: f(x)= -0.4560228655007275
# differential_evolution step 12: f(x)= -0.4560228655007275
# differential_evolution step 13: f(x)= -0.4560228655007275
# differential_evolution step 14: f(x)= -0.4560228655007275
# differential_evolution step 15: f(x)= -0.4560228655007275
# differential_evolution step 16: f(x)= -0.4560228655007275
# differential_evolution step 17: f(x)= -0.4560228655007275
# differential_evolution step 18: f(x)= -0.4560228655007275
# differential_evolution step 19: f(x)= -0.5904421657304597
# differential_evolution step 20: f(x)= -0.5904421657304597
# differential_evolution step 21: f(x)= -0.5904421657304597
# differential_evolution step 22: f(x)= -0.5904421657304597
# differential_evolution step 23: f(x)= -0.5904421657304597
# differential_evolution step 24: f(x)= -0.5904421657304597
# differential_evolution step 25: f(x)= -0.5904421657304597
# differential_evolution step 26: f(x)= -0.5904421657304597
# differential_evolution step 27: f(x)= -0.7029779981367907
# differential_evolution step 28: f(x)= -0.7029779981367907
# differential_evolution step 29: f(x)= -0.7029779981367907
# differential_evolution step 30: f(x)= -0.7029779981367907
# differential_evolution step 31: f(x)= -0.7029779981367907
# differential_evolution step 32: f(x)= -0.7029779981367907
# differential_evolution step 33: f(x)= -0.7029779981367907
# differential_evolution step 34: f(x)= -0.7029779981367907
# differential_evolution step 35: f(x)= -0.7029779981367907
# differential_evolution step 36: f(x)= -0.7029779981367907
# differential_evolution step 37: f(x)= -0.7029779981367907
# differential_evolution step 38: f(x)= -0.7029779981367907
# differential_evolution step 39: f(x)= -0.7029779981367907
# differential_evolution step 40: f(x)= -0.7029779981367907
# differential_evolution step 41: f(x)= -0.7029779981367907
# differential_evolution step 42: f(x)= -0.7029779981367907
# differential_evolution step 43: f(x)= -0.7029779981367907
# differential_evolution step 44: f(x)= -0.7029779981367907
# differential_evolution step 45: f(x)= -0.7029779981367907
# differential_evolution step 46: f(x)= -0.7029779981367907
# differential_evolution step 47: f(x)= -0.7029779981367907
# differential_evolution step 48: f(x)= -0.7029779981367907
# differential_evolution step 49: f(x)= -0.7846775239396885
# differential_evolution step 50: f(x)= -0.7846775239396885
# differential_evolution step 51: f(x)= -0.7846775239396885
# differential_evolution step 52: f(x)= -0.7846775239396885
# differential_evolution step 53: f(x)= -0.7846775239396885
# differential_evolution step 54: f(x)= -0.7846775239396885
# differential_evolution step 55: f(x)= -0.7846775239396885
# differential_evolution step 56: f(x)= -0.7846775239396885
# differential_evolution step 57: f(x)= -0.7846775239396885
# differential_evolution step 58: f(x)= -0.7846775239396885
# differential_evolution step 59: f(x)= -0.7846775239396885
# differential_evolution step 60: f(x)= -0.7846775239396885
# differential_evolution step 61: f(x)= -1.0507677699901306
# differential_evolution step 62: f(x)= -1.0507677699901306
# differential_evolution step 63: f(x)= -1.0507677699901306
# differential_evolution step 64: f(x)= -1.0507677699901306
# differential_evolution step 65: f(x)= -1.0507677699901306
# differential_evolution step 66: f(x)= -1.0507677699901306
# differential_evolution step 67: f(x)= -1.0507677699901306
# differential_evolution step 68: f(x)= -1.0507677699901306
# differential_evolution step 69: f(x)= -1.0507677699901306
# differential_evolution step 70: f(x)= -1.0507677699901306
# differential_evolution step 71: f(x)= -1.0507677699901306
# differential_evolution step 72: f(x)= -1.0507677699901306
# differential_evolution step 73: f(x)= -1.0507677699901306
# differential_evolution step 74: f(x)= -1.0507677699901306
# differential_evolution step 75: f(x)= -1.0553893043744385
# differential_evolution step 76: f(x)= -1.0553893043744385
# differential_evolution step 77: f(x)= -1.0553893043744385
# differential_evolution step 78: f(x)= -1.0553893043744385
# differential_evolution step 79: f(x)= -1.0553893043744385
# differential_evolution step 80: f(x)= -1.1295205344123855
# differential_evolution step 81: f(x)= -1.1295205344123855
# differential_evolution step 82: f(x)= -1.1295205344123855
# differential_evolution step 83: f(x)= -1.1295205344123855
# differential_evolution step 84: f(x)= -1.1849220775414377
# differential_evolution step 85: f(x)= -1.1849220775414377
# differential_evolution step 86: f(x)= -1.1849220775414377
# differential_evolution step 87: f(x)= -1.1849220775414377
# differential_evolution step 88: f(x)= -1.1849220775414377
# differential_evolution step 89: f(x)= -1.1849220775414377
# differential_evolution step 90: f(x)= -1.1849220775414377
# differential_evolution step 91: f(x)= -1.1849220775414377
# differential_evolution step 92: f(x)= -1.1902807974966374
# differential_evolution step 93: f(x)= -1.2082796469799009
# differential_evolution step 94: f(x)= -1.2082796469799009
# differential_evolution step 95: f(x)= -1.2082796469799009
# differential_evolution step 96: f(x)= -1.2146321935181246
# differential_evolution step 97: f(x)= -1.2388493949398887
# differential_evolution step 98: f(x)= -1.2417511157359296
# differential_evolution step 99: f(x)= -1.2417511157359296
# differential_evolution step 100: f(x)= -1.2495615050705504
# differential_evolution step 101: f(x)= -1.2523416585868312
# differential_evolution step 102: f(x)= -1.2523416585868312
# differential_evolution step 103: f(x)= -1.2523416585868312
# differential_evolution step 104: f(x)= -1.2525309601725525
# differential_evolution step 105: f(x)= -1.255303878358258
# differential_evolution step 106: f(x)= -1.255303878358258
# differential_evolution step 107: f(x)= -1.255303878358258
# differential_evolution step 108: f(x)= -1.2557777531348775
# differential_evolution step 109: f(x)= -1.2565893537341635
# differential_evolution step 110: f(x)= -1.2565893537341635
# differential_evolution step 111: f(x)= -1.2566590079805726
# differential_evolution step 112: f(x)= -1.2572997230530092
# differential_evolution step 113: f(x)= -1.257521933115265
# differential_evolution step 114: f(x)= -1.258074967730002
# differential_evolution step 115: f(x)= -1.2585179458674904
# differential_evolution step 116: f(x)= -1.2588185989416312
# differential_evolution step 117: f(x)= -1.2595999535471651
# differential_evolution step 118: f(x)= -1.2599189238541142
# differential_evolution step 119: f(x)= -1.2600567998028869
# differential_evolution step 120: f(x)= -1.2603756032911595
# differential_evolution step 121: f(x)= -1.2604527662787908
# differential_evolution step 122: f(x)= -1.2607329513171979
# differential_evolution step 123: f(x)= -1.2610101978023236
# differential_evolution step 124: f(x)= -1.2611352284887707
# differential_evolution step 125: f(x)= -1.261332493377566
# differential_evolution step 126: f(x)= -1.2614184836301923
# differential_evolution step 127: f(x)= -1.2614838342969492
# differential_evolution step 128: f(x)= -1.2616113647732732
# differential_evolution step 129: f(x)= -1.2616820617585252
# differential_evolution step 130: f(x)= -1.2618521313343678
# differential_evolution step 131: f(x)= -1.2618540102183442
# differential_evolution step 132: f(x)= -1.2620813182991146
# differential_evolution step 133: f(x)= -1.2622337796185257
# differential_evolution step 134: f(x)= -1.2622848134036186
# differential_evolution step 135: f(x)= -1.2623231845974074
# differential_evolution step 136: f(x)= -1.2623868834768621
# differential_evolution step 137: f(x)= -1.262443128052601
# differential_evolution step 138: f(x)= -1.2625356559193317
# differential_evolution step 139: f(x)= -1.2626642920874867
# differential_evolution step 140: f(x)= -1.2627771435801396
# differential_evolution step 141: f(x)= -1.2629920151398941
# differential_evolution step 142: f(x)= -1.263093628849678
# differential_evolution step 143: f(x)= -1.263093628849678
# differential_evolution step 144: f(x)= -1.263140535519945
# differential_evolution step 145: f(x)= -1.2631755372727205
# differential_evolution step 146: f(x)= -1.2632033462602812
# differential_evolution step 147: f(x)= -1.2632033462602812
# differential_evolution step 148: f(x)= -1.2632171051632965
# differential_evolution step 149: f(x)= -1.2632248842077414
# differential_evolution step 150: f(x)= -1.2632321436035652
# differential_evolution step 151: f(x)= -1.2632420205072707
# differential_evolution step 152: f(x)= -1.2632461455795134
# differential_evolution step 153: f(x)= -1.2632597591505925
# differential_evolution step 154: f(x)= -1.2632683892372893
# differential_evolution step 155: f(x)= -1.2632799734997535
# differential_evolution step 156: f(x)= -1.2632799734997535
# differential_evolution step 157: f(x)= -1.2632817958242397
# differential_evolution step 158: f(x)= -1.263292584438244
# differential_evolution step 159: f(x)= -1.2632955429984367
# differential_evolution step 160: f(x)= -1.2633065190906776
# differential_evolution step 161: f(x)= -1.2633132612647968
# differential_evolution step 162: f(x)= -1.2633248510673325
# differential_evolution step 163: f(x)= -1.2633345785912733
# differential_evolution step 164: f(x)= -1.2633445771085055
# differential_evolution step 165: f(x)= -1.2633517753884074
# differential_evolution step 166: f(x)= -1.2633633600466072
# differential_evolution step 167: f(x)= -1.2633721544820764
# differential_evolution step 168: f(x)= -1.2633857644108957
# differential_evolution step 169: f(x)= -1.2633967031331805
# differential_evolution step 170: f(x)= -1.2634079684973314
# differential_evolution step 171: f(x)= -1.263421725680684
# differential_evolution step 172: f(x)= -1.2634406433106395
# differential_evolution step 173: f(x)= -1.2634516978529235
# differential_evolution step 174: f(x)= -1.2634649637447273
# differential_evolution step 175: f(x)= -1.263493767129508
# differential_evolution step 176: f(x)= -1.263511680849633
# differential_evolution step 177: f(x)= -1.2635293196079673
# differential_evolution step 178: f(x)= -1.2635546478599395
# differential_evolution step 179: f(x)= -1.2635724198602498
# differential_evolution step 180: f(x)= -1.2635784826276366
# differential_evolution step 181: f(x)= -1.2635784826276366
# differential_evolution step 182: f(x)= -1.2635803417878557
# differential_evolution step 183: f(x)= -1.2635803417878557
# differential_evolution step 184: f(x)= -1.2635855456286123
# differential_evolution step 185: f(x)= -1.2635855456286123
# differential_evolution step 186: f(x)= -1.263585572039299
# differential_evolution step 187: f(x)= -1.263585572039299
# differential_evolution step 188: f(x)= -1.2635857511959596
# differential_evolution step 189: f(x)= -1.2635888423477368
# differential_evolution step 190: f(x)= -1.263590433925567
# differential_evolution step 191: f(x)= -1.2635907083283882
# differential_evolution step 192: f(x)= -1.2635907083283882
# differential_evolution step 193: f(x)= -1.2635908045217963
# differential_evolution step 194: f(x)= -1.2635929850494843
# differential_evolution step 195: f(x)= -1.2635929850494843
# differential_evolution step 196: f(x)= -1.2635933370051304
# differential_evolution step 197: f(x)= -1.2635933370051304
# differential_evolution step 198: f(x)= -1.263593741286306
# differential_evolution step 199: f(x)= -1.2635937435316538
# differential_evolution step 200: f(x)= -1.2635939703171362
# differential_evolution step 201: f(x)= -1.263594556685171
# differential_evolution step 202: f(x)= -1.2635946199000565
# differential_evolution step 203: f(x)= -1.2635948550354177
# differential_evolution step 204: f(x)= -1.2635948680798592
# differential_evolution step 205: f(x)= -1.2635948680798592
# differential_evolution step 206: f(x)= -1.2635951015695972
# differential_evolution step 207: f(x)= -1.2635953018493584
# differential_evolution step 208: f(x)= -1.2635955745829466
# differential_evolution step 209: f(x)= -1.263595769808088
# differential_evolution step 210: f(x)= -1.2635960954320726
# differential_evolution step 211: f(x)= -1.2635965583930233
# differential_evolution step 212: f(x)= -1.2635968889266427
# differential_evolution step 213: f(x)= -1.2635971590007817
# differential_evolution step 214: f(x)= -1.2635974182972747
# differential_evolution step 215: f(x)= -1.2635976689157997
# differential_evolution step 216: f(x)= -1.2635978169454711
# differential_evolution step 217: f(x)= -1.2635979164886433
# differential_evolution step 218: f(x)= -1.263598031855435
# differential_evolution step 219: f(x)= -1.2635981489556505
# differential_evolution step 220: f(x)= -1.26359826579546
# differential_evolution step 221: f(x)= -1.2635983617523954
# differential_evolution step 222: f(x)= -1.2635984670036091
# differential_evolution step 223: f(x)= -1.2635985855955905
# differential_evolution step 224: f(x)= -1.2635987403546212
# differential_evolution step 225: f(x)= -1.263598849199407
# differential_evolution step 226: f(x)= -1.2635990226329303
# differential_evolution step 227: f(x)= -1.2635991617530618
# differential_evolution step 228: f(x)= -1.2635992294754328
# differential_evolution step 229: f(x)= -1.2635994069383425
# differential_evolution step 230: f(x)= -1.2635997326724466
# differential_evolution step 231: f(x)= -1.26360010530634
# differential_evolution step 232: f(x)= -1.263600468901909
# differential_evolution step 233: f(x)= -1.2636008377298296
# differential_evolution step 234: f(x)= -1.2636011933814029
# differential_evolution step 235: f(x)= -1.2636014029861915
# differential_evolution step 236: f(x)= -1.2636019984354183
# differential_evolution step 237: f(x)= -1.263602282757288
# differential_evolution step 238: f(x)= -1.2636029464663088
# differential_evolution step 239: f(x)= -1.263603508156063
# differential_evolution step 240: f(x)= -1.2636040482103137
# differential_evolution step 241: f(x)= -1.263604477698476
# differential_evolution step 242: f(x)= -1.2636048932207555
# differential_evolution step 243: f(x)= -1.263605144119734
# differential_evolution step 244: f(x)= -1.2636054032432422
# differential_evolution step 245: f(x)= -1.2636056611455506
# differential_evolution step 246: f(x)= -1.2636058589569645
# differential_evolution step 247: f(x)= -1.2636060878285988
# differential_evolution step 248: f(x)= -1.263606423586355
# differential_evolution step 249: f(x)= -1.2636067804579931
# differential_evolution step 250: f(x)= -1.2636069827820964
# differential_evolution step 251: f(x)= -1.2636071752129878
# differential_evolution step 252: f(x)= -1.2636074318458062
# differential_evolution step 253: f(x)= -1.2636075970823277
# differential_evolution step 254: f(x)= -1.2636077702159039
# differential_evolution step 255: f(x)= -1.263607938663561
# differential_evolution step 256: f(x)= -1.2636082602986543
# differential_evolution step 257: f(x)= -1.2636085885538044
# differential_evolution step 258: f(x)= -1.2636090650664014
# differential_evolution step 259: f(x)= -1.2636095473439268
# differential_evolution step 260: f(x)= -1.2636098538840221
# differential_evolution step 261: f(x)= -1.2636102639371507
# differential_evolution step 262: f(x)= -1.2636104498577143
# differential_evolution step 263: f(x)= -1.2636105910994162
# differential_evolution step 264: f(x)= -1.2636107022923009
# differential_evolution step 265: f(x)= -1.2636107788375752
# differential_evolution step 266: f(x)= -1.2636108600518317
# differential_evolution step 267: f(x)= -1.263610941241093
# differential_evolution step 268: f(x)= -1.2636109861194182
# differential_evolution step 269: f(x)= -1.2636110334289403
# differential_evolution step 270: f(x)= -1.2636110767153974
# differential_evolution step 271: f(x)= -1.2636112001152071
# differential_evolution step 272: f(x)= -1.263611314335186
# differential_evolution step 273: f(x)= -1.2636114079171168
# differential_evolution step 274: f(x)= -1.2636115599300002
# differential_evolution step 275: f(x)= -1.2636116759942584
# differential_evolution step 276: f(x)= -1.2636117728374077
# differential_evolution step 277: f(x)= -1.263611852944827
# differential_evolution step 278: f(x)= -1.2636119294867039
# differential_evolution step 279: f(x)= -1.2636119679081164
# differential_evolution step 280: f(x)= -1.263612015756746
# differential_evolution step 281: f(x)= -1.2636120508274076
# differential_evolution step 282: f(x)= -1.263612088136251
# differential_evolution step 283: f(x)= -1.2636121122063857
# differential_evolution step 284: f(x)= -1.2636121416579584
# differential_evolution step 285: f(x)= -1.263612177893924
# differential_evolution step 286: f(x)= -1.2636122002951355
# differential_evolution step 287: f(x)= -1.2636122260548162
# differential_evolution step 288: f(x)= -1.2636122513375283
# differential_evolution step 289: f(x)= -1.2636122742686442
# differential_evolution step 290: f(x)= -1.26361229891251
# differential_evolution step 291: f(x)= -1.2636123175583434
# Polishing solution with 'L-BFGS-B'

# %%
print(DifferentialEvolution_time_frequency_4)
print(results_tf_4)
# Out:
# Index Parameter                 Lower Bound    Found 1             True                 Upper Bound     Status
# ------------------------------------------------------------------------------------------------------------------
# 0     Total_Mass                100000         418879              450000               600000          variable
# 1     Mass_Ratio                0.05           0.999999            0.5                  0.999999        variable
# 2     Spin1                     -1             0.178661            0.2                  1               variable
# 3     Spin2                     -1             0.178659            0.4                  1               variable
# 4     Distance                  1000           4325.18             4000                 10000           variable
# 5     Phase                     0              2.56759             1.5708               6.28319         variable
# 6     cos(Inclination)          -1             -0.514823           0.5                  1               variable
# 7     Ecliptic_Longitude        0              0.577566            3.14159              6.28319         variable
# 8     sin(Ecliptic_Latitude)    -1             -0.176903           0.707107             1               variable
# 9     Polarization              0              0.450779            0.785398             3.14159         variable
# 10    Coalescence_Time          2.49475e+06    2.49996e+06         2.49835e+06          2.54155e+06     variable
#
# SNRs for each run:
# Run 1 : SNR = 1.26361529
#
# [             message: Optimization terminated successfully.
#              success: True
#                  fun: -1.2636152920848167
#                    x: [ 4.189e+05  1.000e+00  1.787e-01  1.787e-01
#                         2.568e+00 -5.148e-01  5.776e-01 -1.769e-01
#                         4.508e-01  2.500e+06]
#                  nit: 291
#                 nfev: 29497
#           population: [[ 4.189e+05  1.000e+00 ...  4.510e-01  2.500e+06]
#                        [ 4.189e+05  1.000e+00 ...  4.506e-01  2.500e+06]
#                        ...
#                        [ 4.189e+05  1.000e+00 ...  4.510e-01  2.500e+06]
#                        [ 4.189e+05  1.000e+00 ...  4.506e-01  2.500e+06]]
#  population_energies: [-1.264e+00 -1.264e+00 ... -1.264e+00 -1.264e+00]
#                  jac: [-1.071e-03 -2.309e-02  1.278e-04 -1.141e-04
#                         3.844e-04  1.921e-04 -5.755e-04  1.555e-04
#                         8.016e-05  1.181e-05]]

# %%
# For full signal, use data_t =  sim.signal_t[0] , set pre_merger=False, and comment   cutoff_index = cutoff_index
# For pre-merger,  use data_t =  data_t_truncated, set pre_merger=True , and uncomment cutoff_index = cutoff_index
differential_evolution_kwargs_5 = {
    'strategy': 'randtobest1exp',
    'popsize': 10,
    'tol': 1e-8,
    'maxiter': 1000,
    'recombination': 1,
    'mutation': (0.5, 1.0),
    'polish': True,
    'disp': True,
    'workers': -1,  # Use all available CPU cores
    'updating': 'deferred',
}

DifferentialEvolution_time_frequency_5 = MBHB_finder_time_frequency(
    data_t = sim.signal_t[0],
    wave_gen= wave_gen,
    waveform_kwargs=waveform_kwargs,
    boundaries=boundaries,
    nperseg=5000,
    dt_full= dt,
    pre_merger=False,
    #cutoff_index=cutoff_index,
    true_parameters=parameters,
)
DifferentialEvolution_time_frequency_5.get_stft_of_data()

found_parameters_tf_5, found_snr_found_tf_5, results_tf_5 = DifferentialEvolution_time_frequency_5.find_MBHB(number_of_searches=number_of_searches,
                                                                             differential_evolution_kwargs=differential_evolution_kwargs_5, 
                                                                             fixed_parameters=fixed_parameters)
# Out:
# time SNR  0.2
# initial guess 0.003294986272816304
# No CuPy
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# differential_evolution step 1: f(x)= -0.14757304082535153
# differential_evolution step 2: f(x)= -0.14757304082535153
# differential_evolution step 3: f(x)= -0.14757304082535153
# differential_evolution step 4: f(x)= -0.14757304082535153
# differential_evolution step 5: f(x)= -0.14757304082535153
# differential_evolution step 6: f(x)= -0.29939577638964887
# differential_evolution step 7: f(x)= -0.29939577638964887
# differential_evolution step 8: f(x)= -0.29939577638964887
# differential_evolution step 9: f(x)= -0.29939577638964887
# differential_evolution step 10: f(x)= -0.29939577638964887
# differential_evolution step 11: f(x)= -0.29939577638964887
# differential_evolution step 12: f(x)= -0.29939577638964887
# differential_evolution step 13: f(x)= -0.29939577638964887
# differential_evolution step 14: f(x)= -0.29939577638964887
# differential_evolution step 15: f(x)= -0.29939577638964887
# differential_evolution step 16: f(x)= -0.3350322708410933
# differential_evolution step 17: f(x)= -0.4512049590400201
# differential_evolution step 18: f(x)= -0.4512049590400201
# differential_evolution step 19: f(x)= -0.4512049590400201
# differential_evolution step 20: f(x)= -0.4512049590400201
# differential_evolution step 21: f(x)= -0.4512049590400201
# differential_evolution step 22: f(x)= -0.4512049590400201
# differential_evolution step 23: f(x)= -0.4512049590400201
# differential_evolution step 24: f(x)= -0.4512049590400201
# differential_evolution step 25: f(x)= -0.4512049590400201
# differential_evolution step 26: f(x)= -0.4512049590400201
# differential_evolution step 27: f(x)= -0.6463599505911194
# differential_evolution step 28: f(x)= -0.6463599505911194
# differential_evolution step 29: f(x)= -0.6463599505911194
# differential_evolution step 30: f(x)= -0.6463599505911194
# differential_evolution step 31: f(x)= -0.6463599505911194
# differential_evolution step 32: f(x)= -0.6463599505911194
# differential_evolution step 33: f(x)= -0.6463599505911194
# differential_evolution step 34: f(x)= -0.6463599505911194
# differential_evolution step 35: f(x)= -0.6463599505911194
# differential_evolution step 36: f(x)= -0.6463599505911194
# differential_evolution step 37: f(x)= -0.6463599505911194
# differential_evolution step 38: f(x)= -0.6463599505911194
# differential_evolution step 39: f(x)= -0.6463599505911194
# differential_evolution step 40: f(x)= -0.6463599505911194
# differential_evolution step 41: f(x)= -0.6463599505911194
# differential_evolution step 42: f(x)= -0.6463599505911194
# differential_evolution step 43: f(x)= -0.6463599505911194
# differential_evolution step 44: f(x)= -0.6463599505911194
# differential_evolution step 45: f(x)= -0.6463599505911194
# differential_evolution step 46: f(x)= -0.6463599505911194
# differential_evolution step 47: f(x)= -0.6463599505911194
# differential_evolution step 48: f(x)= -0.6463599505911194
# differential_evolution step 49: f(x)= -0.6463599505911194
# differential_evolution step 50: f(x)= -0.6463599505911194
# differential_evolution step 51: f(x)= -0.6463599505911194
# differential_evolution step 52: f(x)= -0.6463599505911194
# differential_evolution step 53: f(x)= -0.6463599505911194
# differential_evolution step 54: f(x)= -0.6463599505911194
# differential_evolution step 55: f(x)= -0.6488911919967434
# differential_evolution step 56: f(x)= -0.6488911919967434
# differential_evolution step 57: f(x)= -0.6488911919967434
# differential_evolution step 58: f(x)= -0.6488911919967434
# differential_evolution step 59: f(x)= -0.7033899756479787
# differential_evolution step 60: f(x)= -0.7033899756479787
# differential_evolution step 61: f(x)= -0.7033899756479787
# differential_evolution step 62: f(x)= -0.7033899756479787
# differential_evolution step 63: f(x)= -0.8398468248024649
# differential_evolution step 64: f(x)= -0.8398468248024649
# differential_evolution step 65: f(x)= -0.8398468248024649
# differential_evolution step 66: f(x)= -0.9674685113155493
# differential_evolution step 67: f(x)= -0.9674685113155493
# differential_evolution step 68: f(x)= -0.9674685113155493
# differential_evolution step 69: f(x)= -0.9674685113155493
# differential_evolution step 70: f(x)= -0.9674685113155493
# differential_evolution step 71: f(x)= -0.9674685113155493
# differential_evolution step 72: f(x)= -0.9674685113155493
# differential_evolution step 73: f(x)= -0.9674685113155493
# differential_evolution step 74: f(x)= -0.9674685113155493
# differential_evolution step 75: f(x)= -0.9674685113155493
# differential_evolution step 76: f(x)= -0.9674685113155493
# differential_evolution step 77: f(x)= -0.9674685113155493
# differential_evolution step 78: f(x)= -1.213403616929926
# differential_evolution step 79: f(x)= -1.213403616929926
# differential_evolution step 80: f(x)= -1.213403616929926
# differential_evolution step 81: f(x)= -1.213403616929926
# differential_evolution step 82: f(x)= -1.213403616929926
# differential_evolution step 83: f(x)= -1.213403616929926
# differential_evolution step 84: f(x)= -1.213403616929926
# differential_evolution step 85: f(x)= -1.213403616929926
# differential_evolution step 86: f(x)= -1.213403616929926
# differential_evolution step 87: f(x)= -1.213403616929926
# differential_evolution step 88: f(x)= -1.213403616929926
# differential_evolution step 89: f(x)= -1.213403616929926
# differential_evolution step 90: f(x)= -1.213403616929926
# differential_evolution step 91: f(x)= -1.213403616929926
# differential_evolution step 92: f(x)= -1.213403616929926
# differential_evolution step 93: f(x)= -1.213403616929926
# differential_evolution step 94: f(x)= -1.213403616929926
# differential_evolution step 95: f(x)= -1.213403616929926
# differential_evolution step 96: f(x)= -1.213403616929926
# differential_evolution step 97: f(x)= -1.213403616929926
# differential_evolution step 98: f(x)= -1.213403616929926
# differential_evolution step 99: f(x)= -1.213403616929926
# differential_evolution step 100: f(x)= -1.213403616929926
# differential_evolution step 101: f(x)= -1.213403616929926
# differential_evolution step 102: f(x)= -1.213403616929926
# differential_evolution step 103: f(x)= -1.213403616929926
# differential_evolution step 104: f(x)= -1.213403616929926
# differential_evolution step 105: f(x)= -1.213403616929926
# differential_evolution step 106: f(x)= -1.213403616929926
# differential_evolution step 107: f(x)= -1.213403616929926
# differential_evolution step 108: f(x)= -1.213403616929926
# differential_evolution step 109: f(x)= -1.213403616929926
# differential_evolution step 110: f(x)= -1.213403616929926
# differential_evolution step 111: f(x)= -1.213403616929926
# differential_evolution step 112: f(x)= -1.213403616929926
# differential_evolution step 113: f(x)= -1.213403616929926
# differential_evolution step 114: f(x)= -1.213403616929926
# differential_evolution step 115: f(x)= -1.213403616929926
# differential_evolution step 116: f(x)= -1.213403616929926
# differential_evolution step 117: f(x)= -1.213403616929926
# differential_evolution step 118: f(x)= -1.213403616929926
# differential_evolution step 119: f(x)= -1.213403616929926
# differential_evolution step 120: f(x)= -1.213403616929926
# differential_evolution step 121: f(x)= -1.213403616929926
# differential_evolution step 122: f(x)= -1.213403616929926
# differential_evolution step 123: f(x)= -1.213403616929926
# differential_evolution step 124: f(x)= -1.213403616929926
# differential_evolution step 125: f(x)= -1.213403616929926
# differential_evolution step 126: f(x)= -1.213403616929926
# differential_evolution step 127: f(x)= -1.213403616929926
# differential_evolution step 128: f(x)= -1.213403616929926
# differential_evolution step 129: f(x)= -1.213403616929926
# differential_evolution step 130: f(x)= -1.213403616929926
# differential_evolution step 131: f(x)= -1.213403616929926
# differential_evolution step 132: f(x)= -1.213403616929926
# differential_evolution step 133: f(x)= -1.213403616929926
# differential_evolution step 134: f(x)= -1.213403616929926
# differential_evolution step 135: f(x)= -1.213403616929926
# differential_evolution step 136: f(x)= -1.213403616929926
# differential_evolution step 137: f(x)= -1.213403616929926
# differential_evolution step 138: f(x)= -1.213403616929926
# differential_evolution step 139: f(x)= -1.213403616929926
# differential_evolution step 140: f(x)= -1.213403616929926
# differential_evolution step 141: f(x)= -1.213403616929926
# differential_evolution step 142: f(x)= -1.213403616929926
# differential_evolution step 143: f(x)= -1.213403616929926
# differential_evolution step 144: f(x)= -1.213403616929926
# differential_evolution step 145: f(x)= -1.213403616929926
# differential_evolution step 146: f(x)= -1.213403616929926
# differential_evolution step 147: f(x)= -1.213403616929926
# differential_evolution step 148: f(x)= -1.213403616929926
# differential_evolution step 149: f(x)= -1.213403616929926
# differential_evolution step 150: f(x)= -1.213403616929926
# differential_evolution step 151: f(x)= -1.213403616929926
# differential_evolution step 152: f(x)= -1.213403616929926
# differential_evolution step 153: f(x)= -1.213403616929926
# differential_evolution step 154: f(x)= -1.213403616929926
# differential_evolution step 155: f(x)= -1.213403616929926
# differential_evolution step 156: f(x)= -1.213403616929926
# differential_evolution step 157: f(x)= -1.213403616929926
# differential_evolution step 158: f(x)= -1.213403616929926
# differential_evolution step 159: f(x)= -1.213403616929926
# differential_evolution step 160: f(x)= -1.213403616929926
# differential_evolution step 161: f(x)= -1.213403616929926
# differential_evolution step 162: f(x)= -1.213403616929926
# differential_evolution step 163: f(x)= -1.213403616929926
# differential_evolution step 164: f(x)= -1.213403616929926
# differential_evolution step 165: f(x)= -1.213403616929926
# differential_evolution step 166: f(x)= -1.213403616929926
# differential_evolution step 167: f(x)= -1.213403616929926
# differential_evolution step 168: f(x)= -1.213403616929926
# differential_evolution step 169: f(x)= -1.213403616929926
# differential_evolution step 170: f(x)= -1.213403616929926
# differential_evolution step 171: f(x)= -1.213403616929926
# differential_evolution step 172: f(x)= -1.213403616929926
# differential_evolution step 173: f(x)= -1.213403616929926
# differential_evolution step 174: f(x)= -1.213403616929926
# differential_evolution step 175: f(x)= -1.213403616929926
# differential_evolution step 176: f(x)= -1.2192917319133323
# differential_evolution step 177: f(x)= -1.2338914178763978
# differential_evolution step 178: f(x)= -1.2431385486636584
# differential_evolution step 179: f(x)= -1.2431385486636584
# differential_evolution step 180: f(x)= -1.2442857253273263
# differential_evolution step 181: f(x)= -1.2442857253273263
# differential_evolution step 182: f(x)= -1.2442857253273263
# differential_evolution step 183: f(x)= -1.247933674675033
# differential_evolution step 184: f(x)= -1.2553415070690899
# differential_evolution step 185: f(x)= -1.261235951162753
# differential_evolution step 186: f(x)= -1.261235951162753
# differential_evolution step 187: f(x)= -1.2636501756212035
# differential_evolution step 188: f(x)= -1.2636501756212035
# differential_evolution step 189: f(x)= -1.2641125274865714
# differential_evolution step 190: f(x)= -1.2667861911290217
# differential_evolution step 191: f(x)= -1.270722455449691
# differential_evolution step 192: f(x)= -1.270722455449691
# differential_evolution step 193: f(x)= -1.270722455449691
# differential_evolution step 194: f(x)= -1.270722455449691
# differential_evolution step 195: f(x)= -1.2726679714624516
# differential_evolution step 196: f(x)= -1.2726679714624516
# differential_evolution step 197: f(x)= -1.2739936561307443
# differential_evolution step 198: f(x)= -1.2739936561307443
# differential_evolution step 199: f(x)= -1.2739936561307443
# differential_evolution step 200: f(x)= -1.2739936561307443
# differential_evolution step 201: f(x)= -1.2739936561307443
# differential_evolution step 202: f(x)= -1.274854717706088
# differential_evolution step 203: f(x)= -1.274854717706088
# differential_evolution step 204: f(x)= -1.274854717706088
# differential_evolution step 205: f(x)= -1.27599632993921
# differential_evolution step 206: f(x)= -1.2761914704257926
# differential_evolution step 207: f(x)= -1.2761914704257926
# differential_evolution step 208: f(x)= -1.2761914704257926
# differential_evolution step 209: f(x)= -1.2762924592201947
# differential_evolution step 210: f(x)= -1.276614368786856
# differential_evolution step 211: f(x)= -1.276614368786856
# differential_evolution step 212: f(x)= -1.276614368786856
# differential_evolution step 213: f(x)= -1.276614368786856
# differential_evolution step 214: f(x)= -1.2766849319843294
# differential_evolution step 215: f(x)= -1.2767137230016892
# differential_evolution step 216: f(x)= -1.2767376884998676
# differential_evolution step 217: f(x)= -1.2767581576178346
# differential_evolution step 218: f(x)= -1.2767758787006793
# differential_evolution step 219: f(x)= -1.2768295168517874
# differential_evolution step 220: f(x)= -1.2768295168517874
# differential_evolution step 221: f(x)= -1.2768295168517874
# differential_evolution step 222: f(x)= -1.2768295168517874
# differential_evolution step 223: f(x)= -1.2768295168517874
# differential_evolution step 224: f(x)= -1.2768295168517874
# differential_evolution step 225: f(x)= -1.2768300274761106
# differential_evolution step 226: f(x)= -1.276856825358289
# differential_evolution step 227: f(x)= -1.2768632859830034
# differential_evolution step 228: f(x)= -1.2768954273448088
# differential_evolution step 229: f(x)= -1.2769091130368087
# differential_evolution step 230: f(x)= -1.2769091130368087
# differential_evolution step 231: f(x)= -1.2769154561458302
# differential_evolution step 232: f(x)= -1.2769292952470037
# differential_evolution step 233: f(x)= -1.276942187446626
# differential_evolution step 234: f(x)= -1.27695812823193
# differential_evolution step 235: f(x)= -1.2769640373313262
# differential_evolution step 236: f(x)= -1.2769663668502418
# differential_evolution step 237: f(x)= -1.2769696743724717
# differential_evolution step 238: f(x)= -1.276981808008308
# differential_evolution step 239: f(x)= -1.276984858502018
# differential_evolution step 240: f(x)= -1.2769874846200653
# differential_evolution step 241: f(x)= -1.2769961889130133
# differential_evolution step 242: f(x)= -1.2769961889130133
# differential_evolution step 243: f(x)= -1.277001343273413
# differential_evolution step 244: f(x)= -1.2770084886928728
# differential_evolution step 245: f(x)= -1.2770133031492623
# differential_evolution step 246: f(x)= -1.2770221586531016
# differential_evolution step 247: f(x)= -1.2770235753382893
# differential_evolution step 248: f(x)= -1.2770297429111446
# differential_evolution step 249: f(x)= -1.2770341309085569
# differential_evolution step 250: f(x)= -1.2770406302899646
# differential_evolution step 251: f(x)= -1.2770451231367348
# differential_evolution step 252: f(x)= -1.277050530010891
# differential_evolution step 253: f(x)= -1.2770570184887666
# differential_evolution step 254: f(x)= -1.2770589406807207
# differential_evolution step 255: f(x)= -1.2770661135116457
# differential_evolution step 256: f(x)= -1.277067672145631
# differential_evolution step 257: f(x)= -1.2770705635014077
# differential_evolution step 258: f(x)= -1.277076653102505
# differential_evolution step 259: f(x)= -1.2770843691758271
# differential_evolution step 260: f(x)= -1.2770843691758271
# differential_evolution step 261: f(x)= -1.2770872910652857
# differential_evolution step 262: f(x)= -1.277089316002311
# differential_evolution step 263: f(x)= -1.277089316002311
# differential_evolution step 264: f(x)= -1.277091108814396
# differential_evolution step 265: f(x)= -1.2770949415317088
# differential_evolution step 266: f(x)= -1.2770957494760458
# differential_evolution step 267: f(x)= -1.2771015927089526
# differential_evolution step 268: f(x)= -1.2771028529381108
# differential_evolution step 269: f(x)= -1.2771075246123222
# differential_evolution step 270: f(x)= -1.277115068272299
# differential_evolution step 271: f(x)= -1.2771180027344577
# differential_evolution step 272: f(x)= -1.2771275702190166
# differential_evolution step 273: f(x)= -1.2771287458427563
# differential_evolution step 274: f(x)= -1.2771290857528121
# differential_evolution step 275: f(x)= -1.27712980744342
# differential_evolution step 276: f(x)= -1.2771313342449837
# differential_evolution step 277: f(x)= -1.2771313342449837
# differential_evolution step 278: f(x)= -1.2771313342449837
# differential_evolution step 279: f(x)= -1.2771318351515937
# differential_evolution step 280: f(x)= -1.2771349955038858
# differential_evolution step 281: f(x)= -1.2771349955038858
# differential_evolution step 282: f(x)= -1.277135793805192
# differential_evolution step 283: f(x)= -1.2771370044563097
# differential_evolution step 284: f(x)= -1.2771395412176247
# differential_evolution step 285: f(x)= -1.2771401792043287
# differential_evolution step 286: f(x)= -1.277141200042212
# differential_evolution step 287: f(x)= -1.27714226516331
# differential_evolution step 288: f(x)= -1.2771425284334574
# differential_evolution step 289: f(x)= -1.2771427233593897
# differential_evolution step 290: f(x)= -1.2771431177153643
# differential_evolution step 291: f(x)= -1.2771435390449744
# differential_evolution step 292: f(x)= -1.2771448935438585
# differential_evolution step 293: f(x)= -1.2771459035998005
# differential_evolution step 294: f(x)= -1.2771475300877648
# differential_evolution step 295: f(x)= -1.2771487279064753
# differential_evolution step 296: f(x)= -1.2771502714467147
# differential_evolution step 297: f(x)= -1.277150709697913
# differential_evolution step 298: f(x)= -1.277151120603103
# differential_evolution step 299: f(x)= -1.2771527058839276
# differential_evolution step 300: f(x)= -1.2771527188883307
# differential_evolution step 301: f(x)= -1.277152963052758
# differential_evolution step 302: f(x)= -1.2771538924315147
# differential_evolution step 303: f(x)= -1.277155456671638
# differential_evolution step 304: f(x)= -1.2771559697053148
# differential_evolution step 305: f(x)= -1.2771559697053148
# differential_evolution step 306: f(x)= -1.2771571387631937
# differential_evolution step 307: f(x)= -1.2771577515460935
# differential_evolution step 308: f(x)= -1.2771583054068059
# differential_evolution step 309: f(x)= -1.2771585339696658
# differential_evolution step 310: f(x)= -1.277158728577187
# differential_evolution step 311: f(x)= -1.277159355407744
# differential_evolution step 312: f(x)= -1.2771602286305044
# differential_evolution step 313: f(x)= -1.277160618334478
# differential_evolution step 314: f(x)= -1.277161001568404
# differential_evolution step 315: f(x)= -1.2771616308602427
# differential_evolution step 316: f(x)= -1.277162184909027
# differential_evolution step 317: f(x)= -1.2771631951853313
# differential_evolution step 318: f(x)= -1.2771633484114608
# differential_evolution step 319: f(x)= -1.277164586404939
# differential_evolution step 320: f(x)= -1.2771653715434235
# differential_evolution step 321: f(x)= -1.2771657747114125
# differential_evolution step 322: f(x)= -1.2771660163497076
# differential_evolution step 323: f(x)= -1.2771661544900963
# differential_evolution step 324: f(x)= -1.2771665565530819
# differential_evolution step 325: f(x)= -1.277166892921336
# differential_evolution step 326: f(x)= -1.2771673367403458
# differential_evolution step 327: f(x)= -1.2771680535477503
# differential_evolution step 328: f(x)= -1.2771687178426991
# differential_evolution step 329: f(x)= -1.277168844864276
# differential_evolution step 330: f(x)= -1.2771694810809238
# differential_evolution step 331: f(x)= -1.277169719367292
# differential_evolution step 332: f(x)= -1.2771704124163008
# differential_evolution step 333: f(x)= -1.2771708919629374
# differential_evolution step 334: f(x)= -1.2771720553482364
# differential_evolution step 335: f(x)= -1.2771726359542224
# differential_evolution step 336: f(x)= -1.2771734029890518
# differential_evolution step 337: f(x)= -1.2771734927839598
# differential_evolution step 338: f(x)= -1.2771737923040802
# differential_evolution step 339: f(x)= -1.2771740584994666
# differential_evolution step 340: f(x)= -1.2771748462974761
# differential_evolution step 341: f(x)= -1.277175160858229
# differential_evolution step 342: f(x)= -1.2771756714316473
# differential_evolution step 343: f(x)= -1.2771762509837685
# differential_evolution step 344: f(x)= -1.2771769399399449
# differential_evolution step 345: f(x)= -1.277177991627906
# differential_evolution step 346: f(x)= -1.2771784460286169
# differential_evolution step 347: f(x)= -1.2771796841368708
# differential_evolution step 348: f(x)= -1.2771802965670958
# differential_evolution step 349: f(x)= -1.2771807866184077
# differential_evolution step 350: f(x)= -1.2771807866184077
# differential_evolution step 351: f(x)= -1.2771809274995338
# differential_evolution step 352: f(x)= -1.2771813343103227
# differential_evolution step 353: f(x)= -1.2771817861182004
# differential_evolution step 354: f(x)= -1.2771821745742833
# differential_evolution step 355: f(x)= -1.2771830143577554
# differential_evolution step 356: f(x)= -1.2771844763868905
# differential_evolution step 357: f(x)= -1.277185355303318
# differential_evolution step 358: f(x)= -1.2771861133156786
# differential_evolution step 359: f(x)= -1.2771875533402328
# differential_evolution step 360: f(x)= -1.2771876818883037
# differential_evolution step 361: f(x)= -1.2771881427603582
# differential_evolution step 362: f(x)= -1.277188828200072
# differential_evolution step 363: f(x)= -1.277188828200072
# differential_evolution step 364: f(x)= -1.277189161565487
# differential_evolution step 365: f(x)= -1.2771897966628336
# differential_evolution step 366: f(x)= -1.2771898246171243
# differential_evolution step 367: f(x)= -1.2771905042411595
# differential_evolution step 368: f(x)= -1.2771915326509788
# differential_evolution step 369: f(x)= -1.2771917258523824
# differential_evolution step 370: f(x)= -1.2771923142279074
# differential_evolution step 371: f(x)= -1.2771925854259523
# differential_evolution step 372: f(x)= -1.2771928015324596
# differential_evolution step 373: f(x)= -1.2771933411860756
# differential_evolution step 374: f(x)= -1.2771936926435696
# differential_evolution step 375: f(x)= -1.2771942934327571
# differential_evolution step 376: f(x)= -1.2771949663048194
# differential_evolution step 377: f(x)= -1.2771952296553217
# differential_evolution step 378: f(x)= -1.277196033917455
# differential_evolution step 379: f(x)= -1.2771963927791292
# differential_evolution step 380: f(x)= -1.277196874915266
# differential_evolution step 381: f(x)= -1.2771973525105917
# differential_evolution step 382: f(x)= -1.277197875398135
# differential_evolution step 383: f(x)= -1.2771983694005338
# differential_evolution step 384: f(x)= -1.2771985202922869
# differential_evolution step 385: f(x)= -1.2771989782755948
# differential_evolution step 386: f(x)= -1.277199503002031
# differential_evolution step 387: f(x)= -1.2772001112025073
# differential_evolution step 388: f(x)= -1.2772003621063583
# differential_evolution step 389: f(x)= -1.2772003621063583
# differential_evolution step 390: f(x)= -1.2772005293345192
# differential_evolution step 391: f(x)= -1.277200638082001
# differential_evolution step 392: f(x)= -1.277200638082001
# differential_evolution step 393: f(x)= -1.2772008669470223
# differential_evolution step 394: f(x)= -1.2772012792152838
# differential_evolution step 395: f(x)= -1.2772015338392964
# differential_evolution step 396: f(x)= -1.2772020499604984
# differential_evolution step 397: f(x)= -1.2772021988954518
# differential_evolution step 398: f(x)= -1.2772024208617119
# differential_evolution step 399: f(x)= -1.277202699366185
# differential_evolution step 400: f(x)= -1.2772028694122908
# differential_evolution step 401: f(x)= -1.2772031030794326
# differential_evolution step 402: f(x)= -1.2772032408592477
# differential_evolution step 403: f(x)= -1.2772033705610084
# differential_evolution step 404: f(x)= -1.2772034319207244
# differential_evolution step 405: f(x)= -1.2772035594375948
# differential_evolution step 406: f(x)= -1.277203636126897
# differential_evolution step 407: f(x)= -1.2772037984041518
# differential_evolution step 408: f(x)= -1.2772038935799908
# differential_evolution step 409: f(x)= -1.2772039647714168
# differential_evolution step 410: f(x)= -1.2772039662384636
# differential_evolution step 411: f(x)= -1.2772040547706995
# differential_evolution step 412: f(x)= -1.2772040972140188
# differential_evolution step 413: f(x)= -1.2772041462218395
# differential_evolution step 414: f(x)= -1.2772041895935011
# differential_evolution step 415: f(x)= -1.277204282825482
# differential_evolution step 416: f(x)= -1.2772044222745862
# differential_evolution step 417: f(x)= -1.277204532704527
# differential_evolution step 418: f(x)= -1.2772046525707932
# differential_evolution step 419: f(x)= -1.2772047887708753
# differential_evolution step 420: f(x)= -1.2772049924155842
# differential_evolution step 421: f(x)= -1.2772051300574296
# differential_evolution step 422: f(x)= -1.277205348731645
# differential_evolution step 423: f(x)= -1.2772055095724466
# differential_evolution step 424: f(x)= -1.277205665435864
# differential_evolution step 425: f(x)= -1.2772058349570543
# differential_evolution step 426: f(x)= -1.277205986016227
# differential_evolution step 427: f(x)= -1.2772061609473833
# differential_evolution step 428: f(x)= -1.2772063189422498
# differential_evolution step 429: f(x)= -1.2772064832759142
# differential_evolution step 430: f(x)= -1.277206664498702
# differential_evolution step 431: f(x)= -1.2772066920340894
# differential_evolution step 432: f(x)= -1.2772069266123367
# differential_evolution step 433: f(x)= -1.2772070230347723
# differential_evolution step 434: f(x)= -1.277207118536823
# differential_evolution step 435: f(x)= -1.2772071928133304
# differential_evolution step 436: f(x)= -1.2772073810735893
# differential_evolution step 437: f(x)= -1.277207555898452
# differential_evolution step 438: f(x)= -1.2772077626568836
# differential_evolution step 439: f(x)= -1.2772081027112463
# differential_evolution step 440: f(x)= -1.2772083819568478
# differential_evolution step 441: f(x)= -1.2772086518896892
# differential_evolution step 442: f(x)= -1.2772089972660603
# differential_evolution step 443: f(x)= -1.2772092696757857
# differential_evolution step 444: f(x)= -1.2772093173784127
# differential_evolution step 445: f(x)= -1.2772095871713385
# differential_evolution step 446: f(x)= -1.277209834493553
# differential_evolution step 447: f(x)= -1.2772100132285313
# differential_evolution step 448: f(x)= -1.2772101471673627
# differential_evolution step 449: f(x)= -1.2772102245466317
# differential_evolution step 450: f(x)= -1.2772103815435234
# differential_evolution step 451: f(x)= -1.2772106056085308
# differential_evolution step 452: f(x)= -1.277210680012257
# differential_evolution step 453: f(x)= -1.277210820402997
# differential_evolution step 454: f(x)= -1.2772110523762787
# differential_evolution step 455: f(x)= -1.2772112303835725
# differential_evolution step 456: f(x)= -1.2772114211316596
# differential_evolution step 457: f(x)= -1.277211582868422
# differential_evolution step 458: f(x)= -1.2772117125976645
# differential_evolution step 459: f(x)= -1.2772118057542998
# differential_evolution step 460: f(x)= -1.277212012305879
# differential_evolution step 461: f(x)= -1.2772121183289764
# differential_evolution step 462: f(x)= -1.2772122543577988
# differential_evolution step 463: f(x)= -1.2772123298217255
# differential_evolution step 464: f(x)= -1.277212593463581
# differential_evolution step 465: f(x)= -1.2772128865326993
# differential_evolution step 466: f(x)= -1.2772129598560555
# differential_evolution step 467: f(x)= -1.2772131968237963
# differential_evolution step 468: f(x)= -1.2772133161912576
# differential_evolution step 469: f(x)= -1.2772133529502716
# differential_evolution step 470: f(x)= -1.27721339860102
# differential_evolution step 471: f(x)= -1.277213441782832
# differential_evolution step 472: f(x)= -1.2772135040421146
# differential_evolution step 473: f(x)= -1.2772135865568535
# differential_evolution step 474: f(x)= -1.2772137681160098
# differential_evolution step 475: f(x)= -1.277213822118851
# differential_evolution step 476: f(x)= -1.2772139071527404
# differential_evolution step 477: f(x)= -1.2772139817631558
# differential_evolution step 478: f(x)= -1.2772141320441073
# differential_evolution step 479: f(x)= -1.2772142126616615
# differential_evolution step 480: f(x)= -1.277214252726528
# differential_evolution step 481: f(x)= -1.2772142814849585
# differential_evolution step 482: f(x)= -1.277214374954579
# differential_evolution step 483: f(x)= -1.2772144266099914
# differential_evolution step 484: f(x)= -1.277214435444395
# differential_evolution step 485: f(x)= -1.2772144842808602
# differential_evolution step 486: f(x)= -1.2772144996857782
# differential_evolution step 487: f(x)= -1.2772146462478315
# differential_evolution step 488: f(x)= -1.2772147417120217
# differential_evolution step 489: f(x)= -1.277214800820145
# differential_evolution step 490: f(x)= -1.2772149018676626
# differential_evolution step 491: f(x)= -1.2772149264155217
# differential_evolution step 492: f(x)= -1.2772149746178898
# differential_evolution step 493: f(x)= -1.2772150091687446
# differential_evolution step 494: f(x)= -1.2772150741342425
# differential_evolution step 495: f(x)= -1.2772151705459673
# differential_evolution step 496: f(x)= -1.2772152132643075
# differential_evolution step 497: f(x)= -1.2772152632777383
# differential_evolution step 498: f(x)= -1.2772153082461186
# differential_evolution step 499: f(x)= -1.2772153477486219
# differential_evolution step 500: f(x)= -1.2772154481773206
# differential_evolution step 501: f(x)= -1.2772155103114655
# differential_evolution step 502: f(x)= -1.2772155535951641
# differential_evolution step 503: f(x)= -1.2772156038746312
# differential_evolution step 504: f(x)= -1.2772156186660322
# differential_evolution step 505: f(x)= -1.2772156563776267
# differential_evolution step 506: f(x)= -1.277215716909883
# differential_evolution step 507: f(x)= -1.2772157421465655
# differential_evolution step 508: f(x)= -1.2772157706366603
# differential_evolution step 509: f(x)= -1.2772158236687126
# differential_evolution step 510: f(x)= -1.277215835683213
# differential_evolution step 511: f(x)= -1.277215891901516
# differential_evolution step 512: f(x)= -1.2772159397381195
# differential_evolution step 513: f(x)= -1.2772159681931143
# differential_evolution step 514: f(x)= -1.27721600332782
# differential_evolution step 515: f(x)= -1.2772160337655434
# differential_evolution step 516: f(x)= -1.2772160358785096
# differential_evolution step 517: f(x)= -1.2772160575530638
# differential_evolution step 518: f(x)= -1.2772160889121231
# differential_evolution step 519: f(x)= -1.2772161306931449
# differential_evolution step 520: f(x)= -1.2772161506693835
# differential_evolution step 521: f(x)= -1.2772161655420458
# differential_evolution step 522: f(x)= -1.2772161918391856
# differential_evolution step 523: f(x)= -1.2772162137416057
# differential_evolution step 524: f(x)= -1.2772162184413594
# differential_evolution step 525: f(x)= -1.27721624560118
# differential_evolution step 526: f(x)= -1.277216258263965
# differential_evolution step 527: f(x)= -1.277216273879588
# differential_evolution step 528: f(x)= -1.2772163012705215
# differential_evolution step 529: f(x)= -1.2772163183130787
# differential_evolution step 530: f(x)= -1.2772163349597123
# differential_evolution step 531: f(x)= -1.2772163453909586
# differential_evolution step 532: f(x)= -1.277216363797928
# differential_evolution step 533: f(x)= -1.277216380663729
# differential_evolution step 534: f(x)= -1.277216385521494
# Polishing solution with 'L-BFGS-B'

# %%
print(DifferentialEvolution_time_frequency_5)
print(results_tf_5)
# Out:
# Index Parameter                 Lower Bound    Found 1             True                 Upper Bound     Status
# ------------------------------------------------------------------------------------------------------------------
# 0     Total_Mass                100000         450320              450000               600000          variable
# 1     Mass_Ratio                0.05           0.498232            0.5                  0.999999        variable
# 2     Spin1                     -1             0.202107            0.2                  1               variable
# 3     Spin2                     -1             0.398259            0.4                  1               variable
# 4     Distance                  1000           4082.77             4000                 10000           variable
# 5     Phase                     0              1.57205             1.5708               6.28319         variable
# 6     cos(Inclination)          -1             -0.5024             0.5                  1               variable
# 7     Ecliptic_Longitude        0              0.811128            3.14159              6.28319         variable
# 8     sin(Ecliptic_Latitude)    -1             -0.204866           0.707107             1               variable
# 9     Polarization              0              1.9345              0.785398             3.14159         variable
# 10    Coalescence_Time          2.49475e+06    2.4999e+06          2.49835e+06          2.54155e+06     variable
#
# SNRs for each run:
# Run 1 : SNR = 1.27721639
#
# [             message: Optimization terminated successfully.
#              success: True
#                  fun: -1.2772163863977488
#                    x: [ 4.503e+05  4.982e-01  2.021e-01  3.983e-01
#                         1.572e+00 -5.024e-01  8.111e-01 -2.049e-01
#                         1.934e+00  2.500e+06]
#                  nit: 534
#                 nfev: 53533
#           population: [[ 4.503e+05  4.982e-01 ...  1.934e+00  2.500e+06]
#                        [ 4.503e+05  4.982e-01 ...  1.935e+00  2.500e+06]
#                        ...
#                        [ 4.503e+05  4.984e-01 ...  1.935e+00  2.500e+06]
#                        [ 4.503e+05  4.983e-01 ...  1.935e+00  2.500e+06]]
#  population_energies: [-1.277e+00 -1.277e+00 ... -1.277e+00 -1.277e+00]
#                  jac: [-6.654e-08 -2.178e-03  5.578e-04  1.747e-04
#                         5.449e-05 -4.161e-05  1.123e-03 -7.725e-04
#                         4.485e-06  3.656e-06]]

# %%
# For full signal, use data_t =  sim.signal_t[0] , set pre_merger=False, and comment   cutoff_index = cutoff_index
# For pre-merger,  use data_t =  data_t_truncated, set pre_merger=True , and uncomment cutoff_index = cutoff_index
differential_evolution_kwargs_6 = {
    'strategy': 'best1bin',
    'popsize': 15,
    'tol': 1e-8,
    'maxiter': 1000,
    'recombination': 0.9,
    'mutation': (0.4, 0.8),
    'polish': True,
    'disp': True,
    'workers': -1,
    'updating': 'deferred',
    'init': 'latinhypercube',
}

DifferentialEvolution_time_frequency_6 = MBHB_finder_time_frequency(
    data_t = data_t,
    wave_gen= wave_gen,
    waveform_kwargs=waveform_kwargs,
    boundaries=boundaries,
    nperseg=5000,
    dt_full= dt,
    pre_merger=False,
    #cutoff_index=cutoff_index,
    true_parameters=parameters,
)
DifferentialEvolution_time_frequency_6.get_stft_of_data()

found_parameters_tf_6, found_snr_found_tf_6, results_tf_6 = DifferentialEvolution_time_frequency_6.find_MBHB(number_of_searches=number_of_searches,
                                                                             differential_evolution_kwargs=differential_evolution_kwargs_6, 
                                                                             fixed_parameters=fixed_parameters)
# Out:
# time SNR  0.28
# initial guess -0.010829483362928577
# No CuPy
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# No CuPy
# No CuPy or GPU PhenomHM module.
# No CuPy or GPU interpolation available.
# No CuPy or GPU response available.
# differential_evolution step 1: f(x)= -0.24636867417491112
# differential_evolution step 2: f(x)= -0.24636867417491112
# differential_evolution step 3: f(x)= -0.24636867417491112
# differential_evolution step 4: f(x)= -0.24636867417491112
# differential_evolution step 5: f(x)= -0.32435544353374324
# differential_evolution step 6: f(x)= -0.32435544353374324
# differential_evolution step 7: f(x)= -0.32435544353374324
# differential_evolution step 8: f(x)= -0.32435544353374324
# differential_evolution step 9: f(x)= -0.3471487534789907
# differential_evolution step 10: f(x)= -0.3471487534789907
# differential_evolution step 11: f(x)= -0.3595557883827378
# differential_evolution step 12: f(x)= -0.3595557883827378
# differential_evolution step 13: f(x)= -0.3595557883827378
# differential_evolution step 14: f(x)= -0.3595557883827378
# differential_evolution step 15: f(x)= -0.3801826800345272
# differential_evolution step 16: f(x)= -0.5657958796772776
# differential_evolution step 17: f(x)= -0.5663127082480728
# differential_evolution step 18: f(x)= -0.5663127082480728
# differential_evolution step 19: f(x)= -0.5663127082480728
# differential_evolution step 20: f(x)= -0.5663127082480728
# differential_evolution step 21: f(x)= -0.5663127082480728
# differential_evolution step 22: f(x)= -0.5663127082480728
# differential_evolution step 23: f(x)= -0.5663127082480728
# differential_evolution step 24: f(x)= -0.6221982310716093
# differential_evolution step 25: f(x)= -0.6221982310716093
# differential_evolution step 26: f(x)= -0.6221982310716093
# differential_evolution step 27: f(x)= -0.6221982310716093
# differential_evolution step 28: f(x)= -0.6221982310716093
# differential_evolution step 29: f(x)= -0.6221982310716093
# differential_evolution step 30: f(x)= -0.6221982310716093
# differential_evolution step 31: f(x)= -0.6221982310716093
# differential_evolution step 32: f(x)= -0.6597392010888903
# differential_evolution step 33: f(x)= -0.7468437633745837
# differential_evolution step 34: f(x)= -0.7468437633745837
# differential_evolution step 35: f(x)= -0.7468437633745837
# differential_evolution step 36: f(x)= -0.7468437633745837
# differential_evolution step 37: f(x)= -0.7468437633745837
# differential_evolution step 38: f(x)= -0.7468437633745837
# differential_evolution step 39: f(x)= -0.7468437633745837
# differential_evolution step 40: f(x)= -0.7468437633745837
# differential_evolution step 41: f(x)= -0.7468437633745837
# differential_evolution step 42: f(x)= -0.7468437633745837
# differential_evolution step 43: f(x)= -0.7468437633745837
# differential_evolution step 44: f(x)= -0.7468437633745837
# differential_evolution step 45: f(x)= -0.7468437633745837
# differential_evolution step 46: f(x)= -0.7468437633745837
# differential_evolution step 47: f(x)= -0.7468437633745837
# differential_evolution step 48: f(x)= -0.7468437633745837
# differential_evolution step 49: f(x)= -0.7468437633745837
# differential_evolution step 50: f(x)= -0.7468437633745837
# differential_evolution step 51: f(x)= -0.7468437633745837
# differential_evolution step 52: f(x)= -0.7468437633745837
# differential_evolution step 53: f(x)= -0.7468437633745837
# differential_evolution step 54: f(x)= -0.7468437633745837
# differential_evolution step 55: f(x)= -0.7679832929884421
# differential_evolution step 56: f(x)= -0.7679832929884421
# differential_evolution step 57: f(x)= -0.8151796817791115
# differential_evolution step 58: f(x)= -0.8151796817791115
# differential_evolution step 59: f(x)= -0.8151796817791115
# differential_evolution step 60: f(x)= -0.9122594973898255
# differential_evolution step 61: f(x)= -0.9122594973898255
# differential_evolution step 62: f(x)= -0.9122594973898255
# differential_evolution step 63: f(x)= -0.9306485800807313
# differential_evolution step 64: f(x)= -0.9306485800807313
# differential_evolution step 65: f(x)= -0.9306485800807313
# differential_evolution step 66: f(x)= -0.9306485800807313
# differential_evolution step 67: f(x)= -0.9796426782967022
# differential_evolution step 68: f(x)= -0.9796426782967022
# differential_evolution step 69: f(x)= -0.9796426782967022
# differential_evolution step 70: f(x)= -1.0009660911949705
# differential_evolution step 71: f(x)= -1.0009660911949705
# differential_evolution step 72: f(x)= -1.0543021538304653
# differential_evolution step 73: f(x)= -1.0543021538304653
# differential_evolution step 74: f(x)= -1.0543021538304653
# differential_evolution step 75: f(x)= -1.1393407561455733
# differential_evolution step 76: f(x)= -1.1393407561455733
# differential_evolution step 77: f(x)= -1.141010346694361
# differential_evolution step 78: f(x)= -1.1427065698045995
# differential_evolution step 79: f(x)= -1.1801585039305027
# differential_evolution step 80: f(x)= -1.2005444767305695
# differential_evolution step 81: f(x)= -1.2005444767305695
# differential_evolution step 82: f(x)= -1.2005444767305695
# differential_evolution step 83: f(x)= -1.2005444767305695
# differential_evolution step 84: f(x)= -1.2389645569699097
# differential_evolution step 85: f(x)= -1.2441663641385101
# differential_evolution step 86: f(x)= -1.2441663641385101
# differential_evolution step 87: f(x)= -1.2511580333903825
# differential_evolution step 88: f(x)= -1.2511580333903825
# differential_evolution step 89: f(x)= -1.2513728666079067
# differential_evolution step 90: f(x)= -1.2513728666079067
# differential_evolution step 91: f(x)= -1.2513728666079067
# differential_evolution step 92: f(x)= -1.2513728666079067
# differential_evolution step 93: f(x)= -1.2530312396886816
# differential_evolution step 94: f(x)= -1.2530312396886816
# differential_evolution step 95: f(x)= -1.255389586030123
# differential_evolution step 96: f(x)= -1.2572398174175496
# differential_evolution step 97: f(x)= -1.2583214278554824
# differential_evolution step 98: f(x)= -1.2590244848571501
# differential_evolution step 99: f(x)= -1.259080329707544
# differential_evolution step 100: f(x)= -1.2594507451848838
# differential_evolution step 101: f(x)= -1.2595672660918258
# differential_evolution step 102: f(x)= -1.2597276754371267
# differential_evolution step 103: f(x)= -1.2598995266796111
# differential_evolution step 104: f(x)= -1.260124123040743
# differential_evolution step 105: f(x)= -1.2603383294360422
# differential_evolution step 106: f(x)= -1.2604052183264784
# differential_evolution step 107: f(x)= -1.2604052183264784
# differential_evolution step 108: f(x)= -1.2606442539387956
# differential_evolution step 109: f(x)= -1.2609128289852052
# differential_evolution step 110: f(x)= -1.2611345461519872
# differential_evolution step 111: f(x)= -1.26121944576935
# differential_evolution step 112: f(x)= -1.2614006822154622
# differential_evolution step 113: f(x)= -1.2616851153100794
# differential_evolution step 114: f(x)= -1.2618276010329739
# differential_evolution step 115: f(x)= -1.262086235893702
# differential_evolution step 116: f(x)= -1.2622628753603298
# differential_evolution step 117: f(x)= -1.2624984728254893
# differential_evolution step 118: f(x)= -1.2624984728254893
# differential_evolution step 119: f(x)= -1.2625831412087085
# differential_evolution step 120: f(x)= -1.2626908995964137
# differential_evolution step 121: f(x)= -1.2627098625816824
# differential_evolution step 122: f(x)= -1.2627105167413895
# differential_evolution step 123: f(x)= -1.2627105167413895
# differential_evolution step 124: f(x)= -1.2627105167413895
# differential_evolution step 125: f(x)= -1.2627566218750814
# differential_evolution step 126: f(x)= -1.2627566218750814
# differential_evolution step 127: f(x)= -1.2628008049422703
# differential_evolution step 128: f(x)= -1.2628085810270517
# differential_evolution step 129: f(x)= -1.2628355772725903
# differential_evolution step 130: f(x)= -1.2628355772725903
# differential_evolution step 131: f(x)= -1.2628426914192492
# differential_evolution step 132: f(x)= -1.2628426914192492
# differential_evolution step 133: f(x)= -1.2628426914192492
# differential_evolution step 134: f(x)= -1.2628577772088452
# differential_evolution step 135: f(x)= -1.2628577772088452
# differential_evolution step 136: f(x)= -1.2628585755889152
# differential_evolution step 137: f(x)= -1.2628784379113531
# differential_evolution step 138: f(x)= -1.2628849134751252
# differential_evolution step 139: f(x)= -1.2628904626730193
# differential_evolution step 140: f(x)= -1.2629123693232582
# differential_evolution step 141: f(x)= -1.2629189292332614
# differential_evolution step 142: f(x)= -1.2629277683785518
# differential_evolution step 143: f(x)= -1.2629277683785518
# differential_evolution step 144: f(x)= -1.2629340609563589
# differential_evolution step 145: f(x)= -1.2629446850029178
# differential_evolution step 146: f(x)= -1.262960278249153
# differential_evolution step 147: f(x)= -1.263000698373601
# differential_evolution step 148: f(x)= -1.2630344807499008
# differential_evolution step 149: f(x)= -1.263048679388324
# differential_evolution step 150: f(x)= -1.2630804965996054
# differential_evolution step 151: f(x)= -1.263103912640161
# differential_evolution step 152: f(x)= -1.263115645873896
# differential_evolution step 153: f(x)= -1.263115645873896
# differential_evolution step 154: f(x)= -1.2631190953801839
# differential_evolution step 155: f(x)= -1.2631203845287056
# differential_evolution step 156: f(x)= -1.2631203845287056
# differential_evolution step 157: f(x)= -1.2631281352197568
# differential_evolution step 158: f(x)= -1.2631291347760265
# differential_evolution step 159: f(x)= -1.263129937784263
# differential_evolution step 160: f(x)= -1.263129937784263
# differential_evolution step 161: f(x)= -1.263129937784263
# differential_evolution step 162: f(x)= -1.2631339273738509
# differential_evolution step 163: f(x)= -1.263135904969073
# differential_evolution step 164: f(x)= -1.2631382803382707
# differential_evolution step 165: f(x)= -1.263142042024888
# differential_evolution step 166: f(x)= -1.2631422186962482
# differential_evolution step 167: f(x)= -1.2631422186962482
# differential_evolution step 168: f(x)= -1.2631436272205268
# differential_evolution step 169: f(x)= -1.2631460879675207
# differential_evolution step 170: f(x)= -1.2631468683434037
# differential_evolution step 171: f(x)= -1.263147613247806
# differential_evolution step 172: f(x)= -1.2631486068153586
# differential_evolution step 173: f(x)= -1.263149499628338
# differential_evolution step 174: f(x)= -1.263149499628338
# differential_evolution step 175: f(x)= -1.2631496192224707
# differential_evolution step 176: f(x)= -1.2631497856602452
# differential_evolution step 177: f(x)= -1.2631508709780594
# differential_evolution step 178: f(x)= -1.2631515898653303
# differential_evolution step 179: f(x)= -1.2631538670857378
# differential_evolution step 180: f(x)= -1.2631543330977182
# differential_evolution step 181: f(x)= -1.2631554700723684
# differential_evolution step 182: f(x)= -1.2631564414319736
# differential_evolution step 183: f(x)= -1.2631582921638518
# differential_evolution step 184: f(x)= -1.2631602121528849
# differential_evolution step 185: f(x)= -1.2631618188860974
# differential_evolution step 186: f(x)= -1.2631627267805021
# differential_evolution step 187: f(x)= -1.263165430501072
# differential_evolution step 188: f(x)= -1.263167222900936
# differential_evolution step 189: f(x)= -1.2631691567576349
# differential_evolution step 190: f(x)= -1.2631715314524712
# differential_evolution step 191: f(x)= -1.2631729556700884
# differential_evolution step 192: f(x)= -1.2631744378279348
# differential_evolution step 193: f(x)= -1.2631764325659498
# differential_evolution step 194: f(x)= -1.263177358724526
# differential_evolution step 195: f(x)= -1.2631776767168117
# differential_evolution step 196: f(x)= -1.2631779902190015
# differential_evolution step 197: f(x)= -1.2631783804631536
# differential_evolution step 198: f(x)= -1.2631793890692373
# differential_evolution step 199: f(x)= -1.2631793890692373
# differential_evolution step 200: f(x)= -1.2631804954467096
# differential_evolution step 201: f(x)= -1.2631822482604629
# differential_evolution step 202: f(x)= -1.2631838576176038
# differential_evolution step 203: f(x)= -1.2631860256258896
# differential_evolution step 204: f(x)= -1.2631880508565136
# differential_evolution step 205: f(x)= -1.2631914953287426
# differential_evolution step 206: f(x)= -1.2631931115894315
# differential_evolution step 207: f(x)= -1.2631935798302616
# differential_evolution step 208: f(x)= -1.2631978712105685
# differential_evolution step 209: f(x)= -1.263200031087654
# differential_evolution step 210: f(x)= -1.2632000482835755
# differential_evolution step 211: f(x)= -1.2632015826762604
# differential_evolution step 212: f(x)= -1.263202243016427
# differential_evolution step 213: f(x)= -1.263202489345693
# differential_evolution step 214: f(x)= -1.2632037029789203
# differential_evolution step 215: f(x)= -1.2632043097752566
# differential_evolution step 216: f(x)= -1.2632050470993128
# differential_evolution step 217: f(x)= -1.2632058826315744
# differential_evolution step 218: f(x)= -1.2632072839100579
# differential_evolution step 219: f(x)= -1.2632080500633651
# differential_evolution step 220: f(x)= -1.263208894709554
# differential_evolution step 221: f(x)= -1.2632101964172617
# differential_evolution step 222: f(x)= -1.2632114611919671
# differential_evolution step 223: f(x)= -1.2632131360510828
# differential_evolution step 224: f(x)= -1.2632140824854874
# differential_evolution step 225: f(x)= -1.263214701188027
# differential_evolution step 226: f(x)= -1.2632150758024483
# differential_evolution step 227: f(x)= -1.263215554289601
# differential_evolution step 228: f(x)= -1.26321598588931
# differential_evolution step 229: f(x)= -1.2632165612705433
# differential_evolution step 230: f(x)= -1.263217244553554
# differential_evolution step 231: f(x)= -1.2632175200704183
# differential_evolution step 232: f(x)= -1.2632180146493575
# differential_evolution step 233: f(x)= -1.2632186288102232
# differential_evolution step 234: f(x)= -1.2632194145483069
# differential_evolution step 235: f(x)= -1.263219826151074
# differential_evolution step 236: f(x)= -1.2632201147351363
# differential_evolution step 237: f(x)= -1.2632205930609035
# differential_evolution step 238: f(x)= -1.2632207019359436
# differential_evolution step 239: f(x)= -1.2632218027891606
# differential_evolution step 240: f(x)= -1.2632224275709956
# differential_evolution step 241: f(x)= -1.2632228779091432
# differential_evolution step 242: f(x)= -1.263223701966372
# differential_evolution step 243: f(x)= -1.263224403371132
# differential_evolution step 244: f(x)= -1.263224641650071
# differential_evolution step 245: f(x)= -1.2632249230299795
# differential_evolution step 246: f(x)= -1.263225428235954
# differential_evolution step 247: f(x)= -1.263225802073195
# differential_evolution step 248: f(x)= -1.2632261452686748
# differential_evolution step 249: f(x)= -1.26322650242743
# differential_evolution step 250: f(x)= -1.2632269348884966
# differential_evolution step 251: f(x)= -1.2632271924784275
# differential_evolution step 252: f(x)= -1.263227640946771
# differential_evolution step 253: f(x)= -1.26322817516943
# differential_evolution step 254: f(x)= -1.2632286728032005
# differential_evolution step 255: f(x)= -1.2632288890602734
# differential_evolution step 256: f(x)= -1.263229179469566
# differential_evolution step 257: f(x)= -1.2632292632801394
# differential_evolution step 258: f(x)= -1.2632294755763702
# differential_evolution step 259: f(x)= -1.2632294785940477
# differential_evolution step 260: f(x)= -1.2632297303726652
# differential_evolution step 261: f(x)= -1.2632297462184099
# differential_evolution step 262: f(x)= -1.2632298076880952
# differential_evolution step 263: f(x)= -1.2632298939398394
# differential_evolution step 264: f(x)= -1.2632300724620844
# differential_evolution step 265: f(x)= -1.2632300724620844
# differential_evolution step 266: f(x)= -1.2632301949285554
# differential_evolution step 267: f(x)= -1.2632303576980644
# differential_evolution step 268: f(x)= -1.263230550712793
# differential_evolution step 269: f(x)= -1.2632306005487044
# differential_evolution step 270: f(x)= -1.263230897656155
# differential_evolution step 271: f(x)= -1.263231078250348
# differential_evolution step 272: f(x)= -1.2632312585659329
# differential_evolution step 273: f(x)= -1.2632314612671454
# differential_evolution step 274: f(x)= -1.2632316520640023
# differential_evolution step 275: f(x)= -1.263231701022379
# differential_evolution step 276: f(x)= -1.2632317150291752
# differential_evolution step 277: f(x)= -1.2632317558961819
# differential_evolution step 278: f(x)= -1.2632317869704308
# differential_evolution step 279: f(x)= -1.2632318624960464
# differential_evolution step 280: f(x)= -1.2632318714740465
# differential_evolution step 281: f(x)= -1.2632319266391312
# differential_evolution step 282: f(x)= -1.263232014767707
# differential_evolution step 283: f(x)= -1.263232045405496
# differential_evolution step 284: f(x)= -1.2632321980767218
# differential_evolution step 285: f(x)= -1.2632323561754095
# differential_evolution step 286: f(x)= -1.2632325592659128
# differential_evolution step 287: f(x)= -1.263232790680788
# differential_evolution step 288: f(x)= -1.2632332099633654
# differential_evolution step 289: f(x)= -1.2632338842423634
# differential_evolution step 290: f(x)= -1.2632342087804949
# differential_evolution step 291: f(x)= -1.263234339814087
# differential_evolution step 292: f(x)= -1.2632343427423343
# differential_evolution step 293: f(x)= -1.2632344014166736
# differential_evolution step 294: f(x)= -1.263234462611507
# differential_evolution step 295: f(x)= -1.263234518941124
# differential_evolution step 296: f(x)= -1.263234603146503
# differential_evolution step 297: f(x)= -1.2632346792994058
# differential_evolution step 298: f(x)= -1.2632347098783059
# differential_evolution step 299: f(x)= -1.263234757155047
# differential_evolution step 300: f(x)= -1.263234757155047
# differential_evolution step 301: f(x)= -1.263234810756862
# differential_evolution step 302: f(x)= -1.2632348536021096
# differential_evolution step 303: f(x)= -1.2632349141436687
# differential_evolution step 304: f(x)= -1.2632349817707658
# differential_evolution step 305: f(x)= -1.263235012372396
# differential_evolution step 306: f(x)= -1.2632350455854497
# differential_evolution step 307: f(x)= -1.2632350769633447
# differential_evolution step 308: f(x)= -1.263235091634049
# differential_evolution step 309: f(x)= -1.263235091634049
# differential_evolution step 310: f(x)= -1.263235091634049
# differential_evolution step 311: f(x)= -1.2632351070117545
# differential_evolution step 312: f(x)= -1.2632351070117545
# differential_evolution step 313: f(x)= -1.263235123404617
# differential_evolution step 314: f(x)= -1.263235133031969
# differential_evolution step 315: f(x)= -1.263235133031969
# differential_evolution step 316: f(x)= -1.2632351449337178
# differential_evolution step 317: f(x)= -1.2632351508639934
# differential_evolution step 318: f(x)= -1.2632351719738488
# differential_evolution step 319: f(x)= -1.2632351880387584
# differential_evolution step 320: f(x)= -1.2632352223758012
# differential_evolution step 321: f(x)= -1.2632352618385025
# differential_evolution step 322: f(x)= -1.2632352840984693
# differential_evolution step 323: f(x)= -1.2632353286641915
# differential_evolution step 324: f(x)= -1.2632353598789552
# differential_evolution step 325: f(x)= -1.2632354192235746
# differential_evolution step 326: f(x)= -1.2632354586264314
# differential_evolution step 327: f(x)= -1.2632355170885883
# differential_evolution step 328: f(x)= -1.2632355596269869
# differential_evolution step 329: f(x)= -1.2632356113719534
# differential_evolution step 330: f(x)= -1.2632356940188136
# differential_evolution step 331: f(x)= -1.26323574277271
# differential_evolution step 332: f(x)= -1.2632358106307058
# differential_evolution step 333: f(x)= -1.263235965976848
# differential_evolution step 334: f(x)= -1.2632360389032555
# differential_evolution step 335: f(x)= -1.2632361846861933
# differential_evolution step 336: f(x)= -1.2632363888985876
# differential_evolution step 337: f(x)= -1.2632366279303737
# differential_evolution step 338: f(x)= -1.2632369988971588
# differential_evolution step 339: f(x)= -1.2632374781177542
# differential_evolution step 340: f(x)= -1.2632379326460255
# differential_evolution step 341: f(x)= -1.2632384919256479
# differential_evolution step 342: f(x)= -1.2632387826210072
# differential_evolution step 343: f(x)= -1.2632392848189125
# differential_evolution step 344: f(x)= -1.263239609765792
# differential_evolution step 345: f(x)= -1.2632399162993437
# differential_evolution step 346: f(x)= -1.2632402956513933
# differential_evolution step 347: f(x)= -1.263240604778474
# differential_evolution step 348: f(x)= -1.2632410406517385
# differential_evolution step 349: f(x)= -1.2632412569040192
# differential_evolution step 350: f(x)= -1.2632416121985899
# differential_evolution step 351: f(x)= -1.2632418519652158
# differential_evolution step 352: f(x)= -1.2632420256211947
# differential_evolution step 353: f(x)= -1.263242253730697
# differential_evolution step 354: f(x)= -1.263242412733524
# differential_evolution step 355: f(x)= -1.2632426970470854
# differential_evolution step 356: f(x)= -1.2632428212254354
# differential_evolution step 357: f(x)= -1.2632428212254354
# differential_evolution step 358: f(x)= -1.2632429306292292
# differential_evolution step 359: f(x)= -1.2632431593535727
# differential_evolution step 360: f(x)= -1.2632432715865307
# differential_evolution step 361: f(x)= -1.2632435435152545
# differential_evolution step 362: f(x)= -1.2632436818324828
# differential_evolution step 363: f(x)= -1.2632440784559922
# differential_evolution step 364: f(x)= -1.263244473416337
# differential_evolution step 365: f(x)= -1.2632446069311718
# differential_evolution step 366: f(x)= -1.2632449059783273
# differential_evolution step 367: f(x)= -1.2632451713760164
# differential_evolution step 368: f(x)= -1.2632453479674177
# differential_evolution step 369: f(x)= -1.263245508859463
# differential_evolution step 370: f(x)= -1.2632455837756402
# differential_evolution step 371: f(x)= -1.2632455837756402
# differential_evolution step 372: f(x)= -1.263245628271051
# differential_evolution step 373: f(x)= -1.263245900024608
# differential_evolution step 374: f(x)= -1.263246002736299
# differential_evolution step 375: f(x)= -1.263246132401321
# differential_evolution step 376: f(x)= -1.2632462102013244
# differential_evolution step 377: f(x)= -1.2632463215666052
# differential_evolution step 378: f(x)= -1.2632464581069365
# differential_evolution step 379: f(x)= -1.2632466318028386
# differential_evolution step 380: f(x)= -1.2632469305679237
# differential_evolution step 381: f(x)= -1.2632472121043543
# differential_evolution step 382: f(x)= -1.2632473837729052
# differential_evolution step 383: f(x)= -1.2632476392926137
# differential_evolution step 384: f(x)= -1.2632477770561423
# differential_evolution step 385: f(x)= -1.2632479055029835
# differential_evolution step 386: f(x)= -1.2632479316518375
# differential_evolution step 387: f(x)= -1.263248087259908
# differential_evolution step 388: f(x)= -1.263248171411681
# differential_evolution step 389: f(x)= -1.2632481879444188
# differential_evolution step 390: f(x)= -1.2632481879444188
# differential_evolution step 391: f(x)= -1.2632482140720716
# differential_evolution step 392: f(x)= -1.263248231130308
# differential_evolution step 393: f(x)= -1.2632482483726266
# differential_evolution step 394: f(x)= -1.2632482483726266
# differential_evolution step 395: f(x)= -1.263248251068564
# differential_evolution step 396: f(x)= -1.263248251068564
# differential_evolution step 397: f(x)= -1.263248261722852
# differential_evolution step 398: f(x)= -1.263248281587534
# differential_evolution step 399: f(x)= -1.2632483219637638
# differential_evolution step 400: f(x)= -1.2632483463248514
# differential_evolution step 401: f(x)= -1.263248389622596
# differential_evolution step 402: f(x)= -1.263248418157915
# differential_evolution step 403: f(x)= -1.2632485296673694
# differential_evolution step 404: f(x)= -1.263248613364246
# differential_evolution step 405: f(x)= -1.2632486852490488
# differential_evolution step 406: f(x)= -1.2632488272833855
# differential_evolution step 407: f(x)= -1.2632489429597695
# differential_evolution step 408: f(x)= -1.2632490623241337
# differential_evolution step 409: f(x)= -1.2632492428247062
# differential_evolution step 410: f(x)= -1.263249359537009
# differential_evolution step 411: f(x)= -1.263249462562781
# differential_evolution step 412: f(x)= -1.2632496742957735
# differential_evolution step 413: f(x)= -1.2632496743357886
# differential_evolution step 414: f(x)= -1.263249786043467
# differential_evolution step 415: f(x)= -1.2632498147864604
# differential_evolution step 416: f(x)= -1.2632498716948946
# differential_evolution step 417: f(x)= -1.2632499745999537
# differential_evolution step 418: f(x)= -1.2632500800253736
# differential_evolution step 419: f(x)= -1.263250186710816
# differential_evolution step 420: f(x)= -1.2632503373948158
# differential_evolution step 421: f(x)= -1.2632504241962632
# differential_evolution step 422: f(x)= -1.2632505048524563
# differential_evolution step 423: f(x)= -1.2632505465628219
# differential_evolution step 424: f(x)= -1.2632506649654347
# differential_evolution step 425: f(x)= -1.2632507404640412
# differential_evolution step 426: f(x)= -1.2632509130206504
# differential_evolution step 427: f(x)= -1.2632511209046815
# differential_evolution step 428: f(x)= -1.2632512427269047
# differential_evolution step 429: f(x)= -1.2632514637454522
# differential_evolution step 430: f(x)= -1.2632517032529333
# differential_evolution step 431: f(x)= -1.2632519510514006
# differential_evolution step 432: f(x)= -1.263252175993426
# differential_evolution step 433: f(x)= -1.263252289165132
# differential_evolution step 434: f(x)= -1.263252522675648
# differential_evolution step 435: f(x)= -1.263252772443594
# differential_evolution step 436: f(x)= -1.2632530444594268
# differential_evolution step 437: f(x)= -1.2632534047330783
# differential_evolution step 438: f(x)= -1.26325365218394
# differential_evolution step 439: f(x)= -1.2632540320409675
# differential_evolution step 440: f(x)= -1.2632542782418856
# differential_evolution step 441: f(x)= -1.2632544030859838
# differential_evolution step 442: f(x)= -1.2632545664676509
# differential_evolution step 443: f(x)= -1.2632546403579414
# differential_evolution step 444: f(x)= -1.2632546947505414
# differential_evolution step 445: f(x)= -1.2632548643453823
# differential_evolution step 446: f(x)= -1.2632549331104441
# differential_evolution step 447: f(x)= -1.2632550662271482
# differential_evolution step 448: f(x)= -1.2632551158008596
# differential_evolution step 449: f(x)= -1.263255192070421
# differential_evolution step 450: f(x)= -1.263255310584524
# differential_evolution step 451: f(x)= -1.2632553833653535
# differential_evolution step 452: f(x)= -1.2632554989813487
# differential_evolution step 453: f(x)= -1.263255551781333
# differential_evolution step 454: f(x)= -1.2632556153358157
# differential_evolution step 455: f(x)= -1.263255662737432
# differential_evolution step 456: f(x)= -1.263255688034337
# differential_evolution step 457: f(x)= -1.2632557694654192
# differential_evolution step 458: f(x)= -1.2632558310346167
# differential_evolution step 459: f(x)= -1.2632558671847125
# differential_evolution step 460: f(x)= -1.263255902678795
# differential_evolution step 461: f(x)= -1.263255913714876
# differential_evolution step 462: f(x)= -1.2632559317197796
# differential_evolution step 463: f(x)= -1.263255938666853
# differential_evolution step 464: f(x)= -1.263255943389937
# differential_evolution step 465: f(x)= -1.2632559696378118
# differential_evolution step 466: f(x)= -1.2632559885914
# differential_evolution step 467: f(x)= -1.263255994564799
# differential_evolution step 468: f(x)= -1.2632559953032203
# differential_evolution step 469: f(x)= -1.263256013154486
# differential_evolution step 470: f(x)= -1.2632560195759153
# differential_evolution step 471: f(x)= -1.2632560335553598
# differential_evolution step 472: f(x)= -1.2632560406581563
# differential_evolution step 473: f(x)= -1.2632560524249905
# differential_evolution step 474: f(x)= -1.2632560578245804
# differential_evolution step 475: f(x)= -1.2632560608291337
# differential_evolution step 476: f(x)= -1.2632560619158513
# differential_evolution step 477: f(x)= -1.2632560684391314
# Polishing solution with 'L-BFGS-B'

# %%
print(DifferentialEvolution_time_frequency_6)
print(results_tf_6)
# Out:
# Index Parameter                 Lower Bound    Found 1             True                 Upper Bound     Status
# ------------------------------------------------------------------------------------------------------------------
# 0     Total_Mass                100000         418844              450000               600000          variable
# 1     Mass_Ratio                0.05           0.999999            0.5                  0.999999        variable
# 2     Spin1                     -1             0.17892             0.2                  1               variable
# 3     Spin2                     -1             0.178918            0.4                  1               variable
# 4     Distance                  1000           4266.69             4000                 10000           variable
# 5     Phase                     0              2.59243             1.5708               6.28319         variable
# 6     cos(Inclination)          -1             -0.571439           0.5                  1               variable
# 7     Ecliptic_Longitude        0              6.28319             3.14159              6.28319         variable
# 8     sin(Ecliptic_Latitude)    -1             -0.239352           0.707107             1               variable
# 9     Polarization              0              0.640409            0.785398             3.14159         variable
# 10    Coalescence_Time          2.49475e+06    2.49983e+06         2.49835e+06          2.54155e+06     variable
#
# SNRs for each run:
# Run 1 : SNR = 1.26325607
#
# [             message: Optimization terminated successfully.
#              success: True
#                  fun: -1.2632560696118937
#                    x: [ 4.188e+05  1.000e+00  1.789e-01  1.789e-01
#                         2.592e+00 -5.714e-01  6.283e+00 -2.394e-01
#                         6.404e-01  2.500e+06]
#                  nit: 477
#                 nfev: 71744
#           population: [[ 4.188e+05  1.000e+00 ...  6.404e-01  2.500e+06]
#                        [ 4.188e+05  1.000e+00 ...  6.400e-01  2.500e+06]
#                        ...
#                        [ 4.188e+05  1.000e+00 ...  6.402e-01  2.500e+06]
#                        [ 4.188e+05  1.000e+00 ...  6.402e-01  2.500e+06]]
#  population_energies: [-1.263e+00 -1.263e+00 ... -1.263e+00 -1.263e+00]
#                  jac: [ 4.214e-06 -2.256e-02  7.044e-04 -1.155e-03
#                         1.226e-04  1.095e-05 -1.611e-03 -5.283e-04
#                         9.630e-05  1.056e-05]]

# %%
analysis = TimeFreqSNR(
    data_t,
    wave_gen=wave_gen,
    nperseg=5000,
    dt_full=dt,
    cutoff_index=cutoff_index,
    pre_merger=False
)
analysis.get_stft_of_data()
SNR, amplitude = analysis.calculate_time_frequency_SNR(*parameters, waveform_kwargs=waveform_kwargs)
new_distance = dist /  amplitude
print((new_distance - dist)/(PC_SI*1e9) , (new_distance-dist)/dist)
print( "True distance       = ",  dist/(PC_SI*1e9), "Gpc")
print( "Dist from Amplitude = ",  new_distance/(PC_SI*1e9), "Gpc")
print( "SNR calculated      = ",  SNR)

# Without Noise = 1.2772543789153916
# With Noise    = 1.2772408586383
# Out:
# 4.2342137742266475e-05 1.0585534435566619e-05
# True distance       =  4.0 Gpc
# Dist from Amplitude =  4.000042342137743 Gpc
# SNR calculated      =  1.2772408586383

# %% [markdown]
# # Frequency Domain

# %%
template = wave_gen(*parameters,**waveform_kwargs)[0, :2]

print(likelihood.template_snr(sim.signal_f[0], template, AE1SensitivityMatrix(f_array), df=sim.df))

hh = get_hh(template, AE1SensitivityMatrix(f_array), df=sim.df)
dh = get_dh(sim.signal_f[0], template, AE1SensitivityMatrix(f_array), df=sim.df)
amplitude = dh/hh
new_distance = dist /  amplitude

print( "Percentage diff     = ", (new_distance-dist)*100/dist , "%" )
print( "True distance       = ",  dist/(PC_SI*1e9), "Gpc")
print( "Dist from Amplitude = ",  new_distance/(PC_SI*1e9), "Gpc")
print( "SNR calculated      = " , dh/np.sqrt(hh))

# %%
DifferentialEvolution_frequency_domain= MBHB_finder_frequency_domain(
    data_f=data_f,
    wave_gen=wave_gen,
    waveform_kwargs=waveform_kwargs,
    boundaries=boundaries,
    true_parameters=parameters,
)

DifferentialEvolution_frequency_domain.prepare_data(f_array=f_array, df=sim.df)
found_parameters_fd, found_snr_found_fd, results_fd = DifferentialEvolution_frequency_domain.find_MBHB(number_of_searches=number_of_searches,
                                                                             differential_evolution_kwargs=differential_evolution_kwargs, 
                                                                             fixed_parameters=fixed_parameters)
# The number of messages like "No CuPy or GPU PhenomHM module" you see is exactly equal to the number of workers used. On this macbook, it has 11 cores, so there are 11 messages. Imma just live with this

# %%
print(DifferentialEvolution_frequency_domain), results_fd

# %%
DifferentialEvolution_lisatools= MBHB_finder_lisatools(
    data_f=data_f,
    sens_mat=AE1SensitivityMatrix(f=f_array),
    wave_gen=wave_gen,
    waveform_kwargs=waveform_kwargs,
    f_array=f_array,
    boundaries=boundaries,
    true_parameters=parameters,
)


DifferentialEvolution_lisatools.get_analysis_container_of_data()

found_parameters_lisatools, found_snr_found_lisatools, results_lisatools = DifferentialEvolution_lisatools.find_MBHB(number_of_searches=number_of_searches,
                                                                             differential_evolution_kwargs=differential_evolution_kwargs, 
                                                                             fixed_parameters=fixed_parameters)
# The number of messages like "No CuPy or GPU PhenomHM module" you see is exactly equal to the number of workers used. On this macbook, it has 11 cores, so there are 11 messages. Imma just live with this

# %%
print(DifferentialEvolution_lisatools)
print(results_lisatools)

# %% [markdown]
# - The reason why the distance estimate can be so bad (sometimes even outside the priors) is because it is calculated from the amplitude that is calculated with a template generated by the other found parameters
# - The other found parameters don't have to be close to the true parameters, unless you run it for longer
# - With low tolarance, high popsize, and high maxiter, it works properly but takes a long time to run

# %%
import os
os.system("say 'Computation is done!'")

# %% [markdown]
# # The SNR does not depend on the distance.
# Change the guess_distance to see that the SNR is the same. The distance is calculated based on the amplitude.
# - This only works when all the other parameters in template are set to the real values.
# - The hope is to use differential_evolution to calculate the remaining parameters reasonably well and get an estimate of distance from that

# %%
guess_distance = dist * 1000
signal_with_which_to_test_this = sim.signal_f[0] #data_f
template = wave_gen(
    m1,
    m2,
    a1,
    a2,
    guess_distance, 
    phi_ref,
    f_ref, 
    inc,
    lam,
    beta,
    psi,
    t_ref,
    **waveform_kwargs
)
template = template[0, :2]
print(likelihood.template_snr(signal_with_which_to_test_this, template, AE1SensitivityMatrix(f_array), df=sim.df))

hh = get_hh(template, AE1SensitivityMatrix(f_array), df=sim.df)
dh = get_dh(signal_with_which_to_test_this, template, AE1SensitivityMatrix(f_array), df=sim.df)
amplitude = dh/hh
new_distance = guess_distance /  amplitude

print( "Percentage diff     = ", (new_distance-dist)*100/dist , "%" )
print( "True distance       = ",  dist/(PC_SI*1e9), "Gpc")
print( "Dist from Amplitude = ",  new_distance/(PC_SI*1e9), "Gpc")
print( "SNR calculated      = " , dh/np.sqrt(hh))

# %% [markdown]
# The SNR also does not change with the time-frequency SNR with pre-merger. Change guess_distance and see that nothing changes.
# - Again, this only works when all the other parameters in template are set to the real values.
# - The hope is to use differential_evolution to calculate the remaining parameters reasonably well and get an estimate of distance from that.
# - But it's good that using time-freq SNR also works to get the distance.
# - Change the value of, say, m1 drastically and see that the distance estimate from the equation is awful, which makes sense.

# %%
guess_distance = dist 
parameters_new = [
    m1*(1),  # Slightly change m1 to see the effect
    m2,
    a1*(1),  # Slightly change a1 to see the effect
    a2,
    guess_distance,
    phi_ref,
    f_ref,
    inc*(1 ),
    lam,
    beta,
    psi,
    t_ref
]
analysis = TimeFreqSNR(
    data_t_truncated,
    wave_gen=wave_gen,
    nperseg=5000,
    dt_full=dt,
    cutoff_index=cutoff_index,
    pre_merger=True
)
analysis.get_stft_of_data()
SNR, amplitude = analysis.calculate_time_frequency_SNR(*parameters_new, waveform_kwargs=waveform_kwargs)
new_distance = guess_distance /  amplitude
print((new_distance - dist)/(PC_SI*1e9) , (new_distance-dist)/dist)
print( "True distance       = ",  dist/(PC_SI*1e9), "Gpc")
print( "Dist from Amplitude = ",  new_distance/(PC_SI*1e9), "Gpc")
print( "SNR calculated      = ",  SNR)
